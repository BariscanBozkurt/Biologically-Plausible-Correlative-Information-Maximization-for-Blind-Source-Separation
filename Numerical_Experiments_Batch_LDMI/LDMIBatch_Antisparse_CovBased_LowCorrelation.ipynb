# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
# np.random.seed(14)
# %load_ext autoreload
# %autoreload 2

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.3, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)
S = 2 * S -1 
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.293 & 0.276 & 0.285 & 0.283 & \\
#  0.293 & 1.000 & 0.268 & 0.294 & 0.272 & \\
#  0.276 & 0.268 & 1.000 & 0.273 & 0.263 & \\
#  0.285 & 0.294 & 0.273 & 1.000 & 0.273 & \\
#  0.283 & 0.272 & 0.263 & 0.273 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.857 & -1.966 & 0.886 & 1.120 & -0.190 & \\
#  -0.802 & 0.667 & 0.448 & 0.067 & -1.400 & \\
#  -0.920 & -0.645 & -1.634 & -0.393 & -0.346 & \\
#  -0.638 & 1.357 & 1.059 & 0.456 & 1.531 & \\
#  1.493 & -0.116 & -0.170 & 2.075 & -0.170 & \\
#  0.956 & -0.301 & -0.518 & 0.308 & -0.784 & \\
#  -0.225 & 0.492 & -1.157 & -0.447 & -0.626 & \\
#  -0.594 & 2.199 & -0.431 & -0.703 & 1.497 & \\
#  1.797 & -0.675 & 0.990 & -0.885 & 1.208 & \\
#  1.600 & 0.699 & -1.447 & -0.139 & 0.534 & \\
# \end{bmatrix}$
# Input SNR is : 29.979690325924075

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 200
model = LDMIBSS(s_dim = s_dim, x_dim = x_dim,
                set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch_antisparse(X, epsilon = 1e-5, mu_start = 100, n_iterations = 10000, 
                           method = "covariance", debug_iteration_point = debug_iteration_point,
                           plot_in_jupyter = True)

# %%
W = model.W
Y = W @ X
10 * np.log10(CalculateSINR(Y, S)[0])
# Out:
# 23.98778966643864

# %%
CalculateSIR(A,W)
# Out:
# (33.33120040493891, 5)

# %%
snr(S.T, model.signed_and_permutation_corrected_sources(S.T,Y.T))
# Out:
# array([27.81742898, 29.22942983, 28.35796516, 26.55843607, 16.28355419])

# %%
Y_ = model.signed_and_permutation_corrected_sources(S.T,Y.T)
coef_ = (Y_ * S.T).sum(axis = 0) / (Y_ * Y_).sum(axis = 0)
Y_ = coef_ * Y_
model.snr(S.T,Y_)
# Out:
# array([28.78178547, 30.21047911, 29.46228598, 27.21821888, 17.82961419])
