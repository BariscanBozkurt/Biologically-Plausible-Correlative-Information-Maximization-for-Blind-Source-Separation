# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
# np.random.seed(13)
# %load_ext autoreload
# %autoreload 2

# %%
# Number of sources
r=5
# Number of mixtures
M=10
# Number of samples
N=500000
# SNR level
SNR=30 #dB
NoiseAmp=(10**(-SNR/20))*np.sqrt(r)

#Define number of sampling points
n_samples = N
#Degrees of freedom
df = 4

S = generate_correlated_copula_sources(rho = 0.7, df = 4, n_sources = r, size_sources = N , decreasing_correlation = True)
# S = 2* S - 1
#######################################################
#              GENERATE MIXINGS                       #
#######################################################
# Generate Mxr random mixing from i.i.d N(0,1)
Hm=np.random.randn(M,r)
# Mixtures
HS=np.dot(Hm,S)
NoisePart=NoiseAmp*np.random.randn(HS.shape[0],HS.shape[1])
X=HS+NoisePart
SNRinp=10*np.log10(np.sum(np.var(HS,axis=1))/np.sum(np.var(NoisePart,axis=1)))

# Mean of Mixtures
mX=np.mean(X,axis=1).reshape((M,1))
# Covariance of Mixtures
Rxx=np.dot(X,X.T)/N-np.dot(mX,mX.T)
# Eigenvalue Decomposition
d,V=np.linalg.eig(Rxx)
D=np.diag(d)
#Sorting indexis for eigenvalues from large to small
ie=np.argsort(-d)
# Inverse square root of eigenvalues
ddinv=1/np.sqrt(d[ie[:r]])
# Prewhitining matrix
Wpre=np.dot(np.diag(ddinv),V[:,ie[:r]].T)/np.sqrt(12)
# Whitened Mixtures
H=np.dot(Wpre,X)

# %%
muW = 2e-3
p = 3
bet = 0.1

debug_iteration_point = 500

model = OnlineWhiten(s_dim = r, x_dim = M, muW = muW, p = p, bet = bet)

# %%
model.fit_batch_whiten(X = X, n_epochs = 1, neural_dynamic_iterations = 75, neural_lr_start = .05, 
                       neural_lr_stop = 1e-3, shuffle = True, required_SIR = 90,
                       debug_iteration_point = debug_iteration_point, plot_in_jupyter = True)
# Out:
#  80%|██████████████████████████▍      | 400000/500000 [02:51<00:42, 2329.80it/s]
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Input In [5], in <module>
# ----> 1 model.fit_batch_whiten(X = X, n_epochs = 1, neural_dynamic_iterations = 75, neural_lr_start = .05,
#       2                        neural_lr_stop = 1e-3, shuffle = True, required_SIR = 90,
#       3                        debug_iteration_point = debug_iteration_point, plot_in_jupyter = True)
#
# File ~/Desktop/Files/InfoTheoryBasedNeuralNetworks/LDMI-Based-BSS/src/LDMIBSS.py:960, in OnlineWhiten.fit_batch_whiten(self, X, n_epochs, neural_dynamic_iterations, neural_lr_start, neural_lr_stop, shuffle, required_SIR, debug_iteration_point, plot_in_jupyter)
#     958 # mus = lambd * mus + (1 - lambd) * sk
#     959 if np.mod(i_sample, debug_iteration_point) == 0:
# --> 960     We=np.linalg.pinv((bet+(1-lambd)/p/s_dim)*np.eye(s_dim)-gam/s_dim*B)@Winv*bet
#     961     self.We = We
#     962     Rz=We@Rxx@We.T
#
# File <__array_function__ internals>:5, in pinv(*args, **kwargs)
#
# File ~/anaconda3/envs/wsm/lib/python3.8/site-packages/numpy/linalg/linalg.py:2002, in pinv(a, rcond, hermitian)
#    2000     return wrap(res)
#    2001 a = a.conjugate()
# -> 2002 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2004 # discard small singular values
#    2005 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File <__array_function__ internals>:5, in svd(*args, **kwargs)
#
# File ~/anaconda3/envs/wsm/lib/python3.8/site-packages/numpy/linalg/linalg.py:1660, in svd(a, full_matrices, compute_uv, hermitian)
#    1657         gufunc = _umath_linalg.svd_n_s
#    1659 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1660 u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1661 u = u.astype(result_t, copy=False)
#    1662 s = s.astype(_realType(result_t), copy=False)
#
# File ~/anaconda3/envs/wsm/lib/python3.8/site-packages/numpy/linalg/linalg.py:97, in _raise_linalgerror_svd_nonconvergence(err, flag)
#      96 def _raise_linalgerror_svd_nonconvergence(err, flag):
# ---> 97     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
W = model.compute_overall_mapping()

# %%
display_matrix(np.corrcoef(X))

# %%
display_matrix(np.corrcoef(model.Winv @ X))

# %%
display_matrix(np.corrcoef(W @ X))

# %%
np.std((model.Winv @ X) / np.std(model.Winv @ X, axis = 1).reshape(-1, 1), axis = 1)

# %%
X_ = (model.Winv @ X) / np.std(model.Winv @ X, axis = 1).reshape(-1, 1)
display_matrix(np.corrcoef(X_))

# %%
np.std(X, axis = 1)
