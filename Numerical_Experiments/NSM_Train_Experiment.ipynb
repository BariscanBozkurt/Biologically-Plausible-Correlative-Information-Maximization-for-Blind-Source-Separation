# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
# np.random.seed(13)
# %load_ext autoreload
# %autoreload 2

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, size_sources = N , decreasing_correlation = True)
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

print("The following is the mixture matrix A")
display_matrix(A)

SNR = 30 # dB
NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)
NoisePart = NoiseAmp * np.random.randn(X.shape[0], X.shape[1])
X = X  + NoisePart
SNRinp = 10 * np.log10(np.sum(np.var(X, axis = 1)) / np.sum(np.var(NoisePart, axis = 1)))
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.001 & 0.002 & 0.000 & 0.002 & \\
#  0.001 & 1.000 & 0.000 & -0.003 & -0.001 & \\
#  0.002 & 0.000 & 1.000 & 0.002 & 0.001 & \\
#  0.000 & -0.003 & 0.002 & 1.000 & 0.001 & \\
#  0.002 & -0.001 & 0.001 & 0.001 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.467 & 0.575 & 0.480 & 0.887 & 1.040 & \\
#  -0.367 & 0.234 & 1.346 & 0.143 & 0.019 & \\
#  -0.627 & 1.813 & 0.425 & 0.814 & 0.313 & \\
#  -0.528 & -0.833 & 1.475 & 1.208 & -1.633 & \\
#  0.354 & -0.251 & -0.261 & -0.674 & -0.049 & \\
#  -0.413 & -0.181 & 2.562 & -1.201 & 0.179 & \\
#  -0.941 & -0.398 & 0.575 & 0.322 & 0.260 & \\
#  0.986 & 0.144 & -1.131 & 1.175 & 1.536 & \\
#  0.722 & -1.247 & -0.007 & -1.101 & 0.891 & \\
#  -0.644 & -0.898 & 1.894 & 0.604 & 0.724 & \\
# \end{bmatrix}$
# Input SNR is : 25.529931219893957

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %%
model = OnlineNSM(s_dim = NumberofSources, x_dim = NumberofMixtures, set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch_nsm(X = X, plot_in_jupyter = True)
# Out:
# 100%|██████████████████████████████████| 500000/500000 [11:15<00:00, 740.25it/s]

# %%
model.SIRlist[-1]
# Out:
# 35.09497176020587

# %%
Wnsm = model.compute_overall_mapping(return_mapping=True)
CalculateSIR(A, Wnsm)
# Out:
# (35.239083044584845, 5)
