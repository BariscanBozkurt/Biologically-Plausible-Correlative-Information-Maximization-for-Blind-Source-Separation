# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
# np.random.seed(13)
# %load_ext autoreload
# %autoreload 2

# %%
N = 15000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, size_sources = N , decreasing_correlation = True)
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

print("The following is the mixture matrix A")
display_matrix(A)

SNR = 30 # dB
NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)
NoisePart = NoiseAmp * np.random.randn(X.shape[0], X.shape[1])
X = X  + NoisePart
SNRinp = 10 * np.log10(np.sum(np.var(X, axis = 1)) / np.sum(np.var(NoisePart, axis = 1)))
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.013 & -0.014 & -0.006 & 0.002 & \\
#  -0.013 & 1.000 & 0.001 & -0.001 & 0.008 & \\
#  -0.014 & 0.001 & 1.000 & -0.007 & -0.010 & \\
#  -0.006 & -0.001 & -0.007 & 1.000 & 0.008 & \\
#  0.002 & 0.008 & -0.010 & 0.008 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.259 & 1.434 & -0.629 & -0.248 & 0.851 & \\
#  -0.540 & -1.297 & 0.544 & 1.534 & -0.497 & \\
#  0.991 & -0.131 & -0.755 & 1.526 & -1.034 & \\
#  0.080 & -0.103 & -0.716 & -0.788 & -0.122 & \\
#  0.590 & -0.017 & 0.621 & 0.292 & -0.752 & \\
#  -0.520 & 1.188 & -0.495 & -1.771 & 0.697 & \\
#  -1.658 & 0.268 & 0.076 & -2.238 & -0.594 & \\
#  -0.696 & 0.781 & 0.001 & -1.850 & 0.558 & \\
#  0.012 & 0.098 & 1.111 & 0.352 & 0.634 & \\
#  -0.672 & -0.619 & -0.059 & 0.657 & -2.235 & \\
# \end{bmatrix}$
# Input SNR is : 25.534535138125925

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %%
model = OnlineNSM(s_dim = NumberofSources, x_dim = NumberofMixtures, set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch_nsm(X = X, plot_in_jupyter = True)
# Out:
# 100%|████████████████████████████████████| 15000/15000 [00:19<00:00, 767.18it/s]
