# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from BSMBSS import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.0
N = 500000
NumberofSources = 5
NumberofMixtures = 10

SNR = 30  # dB

S = generate_correlated_copula_sources(
    rho=rho,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=False,
)

S = 2 * S - 1
A = np.random.standard_normal(size=(NumberofMixtures, NumberofSources))
X = A @ S

X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)

print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.342 & 0.503 & 0.400 & 1.072 & 0.155 & \\
#  -0.522 & 0.069 & -0.096 & -2.197 & 0.994 & \\
#  -0.357 & -0.706 & 0.385 & 0.633 & -0.408 & \\
#  -0.479 & -0.349 & -1.399 & 0.090 & 0.048 & \\
#  -0.146 & 0.050 & 1.227 & -0.016 & 0.057 & \\
#  0.193 & 0.882 & 0.504 & -0.511 & 0.955 & \\
#  -0.423 & -1.843 & 0.500 & -1.052 & 0.140 & \\
#  -1.597 & 0.279 & 0.125 & -1.221 & 0.184 & \\
#  -0.305 & -0.420 & -1.252 & 0.431 & 1.076 & \\
#  1.108 & 1.194 & -0.066 & -1.414 & -1.273 & \\
# \end{bmatrix}$
# Input SNR is : 30.003503508887256

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
debug_iteration_point = 25000
gamma = np.sqrt(1 - 4e-3)
W = np.eye(NumberofSources)
M = np.eye(NumberofSources)

# %% [markdown]
# # Run BSM Algorithm on Mixture Signals

# %%
model = OnlineBSM(
    s_dim=NumberofSources,
    x_dim=NumberofMixtures,
    beta=1e-6,
    gamma=gamma,
    whiten_input_=True,
    W=W,
    M=M,
    neural_OUTPUT_COMP_TOL=1e-7,
    set_ground_truth=True,
    S=S,
    A=A,
)
with Timer() as t:
    model.fit_batch_antisparse(
        X=X,
        n_epochs=1,
        neural_dynamic_iterations=10,
        neural_lr_start=0.9,
        neural_lr_stop=1e-15,
        fast_start=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
print("Algorithm took %f sec." % (t.interval))
# Out:
# 100%|██████████| 500000/500000 [01:26<00:00, 5788.31it/s]
# Algorithm took 86.641101 sec.

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [24.96153058 29.81952149 24.52632445 23.51550905 26.32893922]
#
# Overall SINR : 25.352370959076236

# %%
CalculateSIR(A, Wf)
# Out:
# (26.90611596917804, 5)

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
