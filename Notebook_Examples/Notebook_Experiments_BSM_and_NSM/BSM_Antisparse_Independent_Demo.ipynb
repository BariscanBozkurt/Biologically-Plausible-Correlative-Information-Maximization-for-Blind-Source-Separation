# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from BSMBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.0
N = 500000
NumberofSources = 5
NumberofMixtures = 10

SNR = 30 # dB

S = generate_correlated_copula_sources(rho = rho, df = 4, n_sources = NumberofSources, size_sources = N , 
                                       decreasing_correlation = False)

S  = 2 * S - 1
A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
X = A @ S

X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))

print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -1.168 & -1.187 & -0.511 & 0.725 & 0.711 & \\
#  -0.664 & 0.761 & -0.303 & -1.093 & 0.158 & \\
#  -1.164 & 1.256 & 0.867 & 0.538 & 0.176 & \\
#  0.417 & -0.627 & -0.332 & 0.548 & -0.421 & \\
#  0.022 & 0.937 & -0.848 & 0.425 & -1.764 & \\
#  -0.797 & -0.624 & 1.725 & 1.150 & -1.035 & \\
#  -1.052 & 1.614 & -0.166 & 0.614 & -1.055 & \\
#  -0.541 & -1.451 & 0.149 & -2.337 & -0.913 & \\
#  1.163 & -0.981 & -0.704 & 0.474 & 2.314 & \\
#  -1.259 & 2.074 & 0.490 & -0.922 & 0.884 & \\
# \end{bmatrix}$
# Input SNR is : 30.004081141364544

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
debug_iteration_point = 25000
gamma = np.sqrt(1 - 4e-3)
W = np.eye(NumberofSources)
M = np.eye(NumberofSources)

# %% [markdown]
# # Run BSM Algorithm on Mixture Signals

# %%
model = OnlineBSM(s_dim = NumberofSources, x_dim = NumberofMixtures, beta = 1e-6, 
                  gamma = gamma, whiten_input_ = True,
                  W = W, M = M,
                  neural_OUTPUT_COMP_TOL = 1e-7,
                  set_ground_truth = True, S = S, A = A)
with Timer() as t:
    model.fit_batch_antisparse(X = X, n_epochs = 1, neural_dynamic_iterations = 10,
                               neural_lr_start = 0.9, neural_lr_stop = 1e-15, 
                               fast_start = True, debug_iteration_point = debug_iteration_point,
                               plot_in_jupyter = True)
print('Algorithm took %f sec.' % (t.interval))
# Out:
# 100%|██████████| 500000/500000 [01:49<00:00, 4580.15it/s]
# Algorithm took 109.368489 sec.

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [26.70898914 28.0575746  25.11587359 27.8017922  27.86860595]
#
# Overall SINR : 26.95113869482252

# %%
CalculateSIR(A, Wf)
# Out:
# (28.9290642352734, 5)

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
