# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from polytope_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "General_Polytope"

# %%
seed_ = np.random.randint(50000)
seed_ = 48948
print(seed_)
np.random.seed(seed_)
# Out:
# 48948

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
dim = 6
N = 500000
NumberofSources = dim
NumberofMixtures = 12

signed_dims = np.array([0, 1, 2, 3])
nn_dims = np.array([4, 5])
sparse_dims_list = [np.array([0, 1, 4, 5])]
(A, b), V = generate_practical_polytope(dim, signed_dims, nn_dims, sparse_dims_list)
S = generate_uniform_points_in_polytope(V, N)

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
plt.scatter(S[0, :], S[1, :])
plt.xlabel("$S_{:,1}$", fontsize=25)
plt.ylabel("$S_{:,2}$", fontsize=25)
plt.grid(linewidth=0.2)
plt.subplot(1, 3, 2)
plt.scatter(S[0, :], S[2, :])
plt.xlabel("$S_{:,1}$", fontsize=25)
plt.ylabel("$S_{:,3}$", fontsize=25)
plt.grid(linewidth=0.2)
plt.subplot(1, 3, 3)
plt.scatter(S[1, :], S[2, :])
plt.xlabel("$S_{:,2}$", fontsize=25)
plt.ylabel("$S_{:,3}$", fontsize=25)
plt.grid(linewidth=0.2)

plt.suptitle("Scatter Plot of Source Components", fontsize=30)
# plt.savefig('Pex_source_components.pdf', format='pdf', dpi = 1200)
# Out:
# Text(0.5, 0.98, 'Scatter Plot of Source Components')

# %%
# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.266 & -0.931 & -0.148 & 0.477 & 0.875 & 1.912 & \\
#  -0.226 & -0.548 & 0.507 & -0.891 & -0.318 & -0.802 & \\
#  1.171 & 0.576 & 0.931 & 0.052 & -0.465 & 0.624 & \\
#  -0.142 & -1.042 & 0.384 & -0.301 & 0.933 & -1.618 & \\
#  0.431 & -0.102 & 0.498 & 0.038 & 0.865 & -1.610 & \\
#  1.293 & 0.404 & -0.119 & -0.107 & 1.042 & 0.515 & \\
#  1.772 & -0.703 & -0.062 & -0.076 & 0.505 & 0.572 & \\
#  0.021 & -1.932 & -0.052 & -1.926 & 1.255 & 0.214 & \\
#  0.112 & 0.315 & 0.954 & -0.685 & -1.001 & -0.883 & \\
#  -1.530 & -0.863 & 0.857 & 0.115 & -0.371 & -0.464 & \\
#  0.345 & 0.294 & 0.140 & -0.224 & -0.078 & 0.823 & \\
#  0.179 & -0.098 & 0.056 & -0.873 & 1.826 & 2.086 & \\
# \end{bmatrix}$
# Input SNR is : 29.99810243930407

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
lambday = 1 - 1e-1 / 10
lambdae = 1 - 1e-1 / 10
s_dim = S.shape[0]
x_dim = X.shape[0]

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 1000 * np.eye(s_dim)

debug_iteration_point = 25000
model = OnlineCorInfoMax(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=50 * 1e-3,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=True,
    S=S,
    A=A,
)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_general_polytope(
        X=X,
        signed_dims=signed_dims,
        nn_dims=nn_dims,
        sparse_dims_list=sparse_dims_list,
        n_epochs=1,
        neural_dynamic_iterations=500,
        plot_in_jupyter=True,
        neural_lr_start=0.25,
        neural_lr_stop=1e-10,
        stlambd_lr=0.01,
        debug_iteration_point=debug_iteration_point,
        shuffle=True,
    )
print("Algorithm took %f sec." % (t.interval))
# Out:
#  16%|█▋        | 82465/500000 [01:26<04:43, 1471.13it/s]

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    model.SIR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

print("Final SIR: {}".format(np.array(model.SIR_list[-1])))

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping=True)
Y_ = Wf @ X
Y_ = model.signed_and_permutation_corrected_sources(S, Y_)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10 * np.log10(CalculateSINRjit(Y_, S, False)[0])

print("Overall SINR : {}".format(SINR))

# %%
Szeromean = S - S.mean(axis=1).reshape(-1, 1)
Wf = model.compute_overall_mapping(return_mapping=True)
Y_ = Wf @ X
Yzeromean = Y_ - Y_.mean(axis=1).reshape(-1, 1)
Y_ = model.signed_and_permutation_corrected_sources(Szeromean, Yzeromean)
coef_ = ((Y_ * Szeromean).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Szeromean, Y_)))

SINR = 10 * np.log10(CalculateSINRjit(Y_, Szeromean, False)[0])

print("Overall SINR : {}".format(SINR))

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    Szeromean[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
