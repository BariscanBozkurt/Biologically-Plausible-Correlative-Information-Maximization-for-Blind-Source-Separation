# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from polytope_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'General_Polytope'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
dim = 5
N = 500000
NumberofSources = dim
NumberofMixtures = 10

signed_dims = np.array([0,1,4])
nn_dims = np.array([2,3])
sparse_dims_list = []
(A,b), V = generate_practical_polytope(dim, signed_dims, nn_dims, sparse_dims_list)
S = generate_uniform_points_in_polytope(V, N)

# %%
plt.figure(figsize = (20,5))
plt.subplot(1,3,1)
plt.scatter(S[0,:], S[1,:])
plt.xlabel("$S_{:,1}$", fontsize = 25)
plt.ylabel("$S_{:,2}$", fontsize = 25)
plt.grid(linewidth=.2)
plt.subplot(1,3,2)
plt.scatter(S[0,:], S[2,:])
plt.xlabel("$S_{:,1}$", fontsize = 25)
plt.ylabel("$S_{:,3}$", fontsize = 25)
plt.grid(linewidth=.2)
plt.subplot(1,3,3)
plt.scatter(S[1,:], S[2,:])
plt.xlabel("$S_{:,2}$", fontsize = 25)
plt.ylabel("$S_{:,3}$", fontsize = 25)
plt.grid(linewidth=.2)

plt.suptitle("Scatter Plot of Source Components", fontsize = 30)
# plt.savefig('Pex_source_components.pdf', format='pdf', dpi = 1200)
# Out:
# Text(0.5, 0.98, 'Scatter Plot of Source Components')

# %%
# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.099 & 0.607 & -1.093 & 0.323 & 0.882 & \\
#  1.229 & 1.235 & 0.788 & -0.921 & 0.654 & \\
#  -0.736 & 2.175 & -0.102 & -0.316 & 1.332 & \\
#  1.450 & -1.872 & 1.880 & 0.386 & -0.324 & \\
#  -0.269 & -0.039 & -0.986 & 0.178 & -1.126 & \\
#  -1.453 & 0.758 & 0.813 & -0.230 & 0.167 & \\
#  -1.302 & 0.977 & -0.069 & -0.208 & 1.425 & \\
#  1.220 & 1.262 & -0.656 & -0.563 & -0.609 & \\
#  -1.636 & -0.114 & 1.331 & -1.052 & -0.418 & \\
#  -0.693 & 0.979 & -1.062 & 0.377 & -0.731 & \\
# \end{bmatrix}$
# Input SNR is : 30.005003892424234

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
lambday = 1 - 1e-1/10
lambdae = 1 - 1e-1/10
s_dim = S.shape[0]
x_dim = X.shape[0]

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 1000 * np.eye(s_dim)

debug_iteration_point = 25000
model = OnlineCorInfoMax(s_dim = s_dim, x_dim = x_dim, muW = 50*1e-3, lambday = lambday,
                         lambdae = lambdae, By = By, Be = Be, neural_OUTPUT_COMP_TOL = 1e-6,
                         set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_general_polytope(X = X, signed_dims = signed_dims, nn_dims = nn_dims,
                                     sparse_dims_list = sparse_dims_list,n_epochs = 1, neural_dynamic_iterations = 500,
                                     plot_in_jupyter = True, neural_lr_start = 0.2, neural_lr_stop = 1e-10,
                                     debug_iteration_point = debug_iteration_point, 
                                     shuffle = True)
print('Algorithm took %f sec.' % (t.interval))
# Out:
#   5%|▌         | 25047/500000 [01:06<1:31:48, 86.22it/s]
# SVD did not converge
#  10%|█         | 50057/500000 [02:37<1:45:17, 71.22it/s]
# SVD did not converge
#  15%|█▌        | 75063/500000 [04:11<1:08:40, 103.12it/s]
# SVD did not converge
#  20%|██        | 100064/500000 [05:37<1:04:41, 103.03it/s]
# SVD did not converge
#  25%|██▌       | 125068/500000 [07:04<1:01:33, 101.51it/s]
# SVD did not converge
#  30%|███       | 150066/500000 [08:39<56:15, 103.66it/s]
# SVD did not converge
#  35%|███▌      | 175075/500000 [10:05<53:14, 101.71it/s]
# SVD did not converge
#  40%|████      | 200080/500000 [11:32<48:24, 103.25it/s]
# SVD did not converge
#  45%|████▌     | 225068/500000 [12:59<44:15, 103.52it/s]
# SVD did not converge
#  50%|█████     | 250082/500000 [14:26<39:52, 104.48it/s]
# SVD did not converge
#  55%|█████▌    | 275066/500000 [15:52<41:24, 90.53it/s]
# SVD did not converge
#  60%|██████    | 300062/500000 [17:17<41:56, 79.45it/s]
# SVD did not converge
#  65%|██████▌   | 325084/500000 [18:46<28:38, 101.79it/s]
# SVD did not converge
#  70%|███████   | 350077/500000 [20:14<24:38, 101.43it/s]
# SVD did not converge
#  75%|███████▌  | 375064/500000 [21:41<20:13, 102.92it/s]
# SVD did not converge
#  80%|████████  | 400068/500000 [23:08<18:01, 92.36it/s]
# SVD did not converge
#  85%|████████▌ | 425066/500000 [24:37<12:11, 102.46it/s]
# SVD did not converge
#  90%|█████████ | 450061/500000 [26:10<09:14, 90.03it/s]
# SVD did not converge
#  95%|█████████▌| 475033/500000 [27:53<05:55, 70.21it/s]
# SVD did not converge
# 100%|██████████| 500000/500000 [29:38<00:00, 281.09it/s]
# SVD did not converge
# Algorithm took 1778.957437 sec.

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(model.SIR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

print('Final SIR: {}'.format(np.array(model.SIR_list[-1])))
# Out:
# Final SIR: -0.23314246970503827

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Szeromean = S - S.mean(axis = 1).reshape(-1,1)
Wf = model.compute_overall_mapping(return_mapping = True)
Y_ = Wf @ X
Yzeromean = Y_ - Y_.mean(axis = 1).reshape(-1,1)
Y_ = model.signed_and_permutation_corrected_sources(Szeromean,Yzeromean)
coef_ = ((Y_ * Szeromean).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Szeromean, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, Szeromean, False)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [nan nan nan nan nan]
#
# Overall SINR : nan

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Szeromean[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
