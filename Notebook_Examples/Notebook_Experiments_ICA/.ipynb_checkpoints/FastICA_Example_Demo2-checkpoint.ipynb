# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from ICA import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "FastICA"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
# Generate the sources and mixtures
S, X, A = generate_synthetic_data_SMICA(seed=np.random.randint(2500))

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Run FastICA Algorithm on Mixture Signals

# %%
NumberofSources = 4
NumberofMixtures = NumberofSources
model = FastICA(s_dim=NumberofSources, x_dim=NumberofMixtures)

# %%
Y = model.fit_transform(X, n_epochs=1)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.04it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [110.50926696  48.47539679  32.64365454  28.49498905]
#
# Overall SINR : 31.05288282129988

# %%
Y = model.predict(X)
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [110.50926787  48.47593236  32.64323163  28.1310146 ]
#
# Overall SINR : 31.05260520009746

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
