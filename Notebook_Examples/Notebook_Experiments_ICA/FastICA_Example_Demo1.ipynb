# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from ICA import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'FastICA'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = True)

S = 2 * S - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.001 & 0.002 & 0.000 & -0.000 & \\
#  0.001 & 1.000 & 0.001 & -0.001 & 0.001 & \\
#  0.002 & 0.001 & 1.000 & 0.000 & 0.001 & \\
#  0.000 & -0.001 & 0.000 & 1.000 & -0.001 & \\
#  -0.000 & 0.001 & 0.001 & -0.001 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.141 & -0.682 & 0.057 & 1.373 & 1.873 & \\
#  1.720 & 0.084 & 0.020 & 0.395 & -0.397 & \\
#  -1.016 & 0.228 & -0.573 & 1.804 & 0.313 & \\
#  -0.761 & 0.240 & -0.113 & -0.636 & -0.007 & \\
#  -1.514 & -1.953 & 0.096 & 0.923 & 0.320 & \\
#  0.161 & -0.330 & -0.749 & 1.407 & 0.449 & \\
#  1.527 & 1.918 & 1.949 & 0.151 & -0.713 & \\
#  2.011 & -0.928 & -0.160 & 0.214 & -0.507 & \\
#  -0.991 & 0.221 & 0.063 & 0.206 & 0.375 & \\
#  -1.802 & 1.063 & 0.109 & 0.363 & -0.490 & \\
# \end{bmatrix}$
# Input SNR is : 29.99856757003262

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Run FastICA Algorithm on Mixture Signals

# %%
model = FastICA(s_dim = NumberofSources, x_dim = NumberofMixtures)

# %%
Y = model.fit_transform(X)
# Out:
# 100%|██████████| 1/1 [00:39<00:00, 39.15s/it]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [34.65059792 29.74685553 25.91061074 31.04185156 27.27661431]
#
# Overall SINR : 28.774616812036054

# %%
Y = model.predict(X)
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [34.61220433 29.74550991 25.90738908 31.03884137 27.27642835]
#
# Overall SINR : 28.774611897997925

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %% [markdown]
# # Trial of FastICA from Scikit-Learn

# %%
from sklearn.decomposition import FastICA

# %%
transformer = FastICA(n_components=5,
         random_state=0,
         whiten='unit-variance')

# %%
Ysklearn = transformer.fit_transform(X.T).T

# %%
10*np.log10(CalculateSINR(Ysklearn, S)[0])
# Out:
# 28.76750616912431
