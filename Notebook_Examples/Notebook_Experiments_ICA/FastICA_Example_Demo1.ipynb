# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from ICA import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "FastICA"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(
    rho=0.0,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)

S = 2 * S - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.002 & 0.001 & 0.002 & -0.002 & \\
#  -0.002 & 1.000 & -0.000 & 0.001 & 0.001 & \\
#  0.001 & -0.000 & 1.000 & 0.001 & 0.005 & \\
#  0.002 & 0.001 & 0.001 & 1.000 & -0.001 & \\
#  -0.002 & 0.001 & 0.005 & -0.001 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.636 & 0.152 & 0.464 & -1.803 & 0.600 & \\
#  0.264 & 0.395 & 0.264 & -0.350 & -0.221 & \\
#  -0.114 & 0.147 & 0.697 & 0.672 & -0.812 & \\
#  1.159 & 0.556 & -0.537 & -0.457 & -0.674 & \\
#  -0.223 & -0.687 & 1.276 & -1.155 & -1.999 & \\
#  0.968 & 0.555 & -0.156 & -0.815 & -1.061 & \\
#  0.426 & 1.867 & -0.300 & -1.000 & -0.130 & \\
#  1.109 & 1.309 & 1.061 & -2.087 & -1.012 & \\
#  -0.589 & 0.646 & -0.217 & 0.029 & 0.637 & \\
#  0.535 & -0.071 & -0.334 & 0.416 & 0.577 & \\
# \end{bmatrix}$
# Input SNR is : 30.000946382720727

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Run FastICA Algorithm on Mixture Signals

# %%
model = FastICA(s_dim=NumberofSources, x_dim=NumberofMixtures)

# %%
Y = model.fit_transform(X)
# Out:
# 100%|██████████| 1/1 [01:03<00:00, 63.56s/it]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [27.50608919 29.41090333 25.27818379 30.02914909 29.2830013 ]
#
# Overall SINR : 27.921003370959056

# %%
Y = model.predict(X)
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINR(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [27.50609644 29.41027984 25.27280464 30.02884765 29.28222379]
#
# Overall SINR : 27.92099970530129

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)

# %% [markdown]
# # Trial of FastICA from Scikit-Learn

# %%
from sklearn.decomposition import FastICA

# %%
transformer = FastICA(n_components=5, random_state=0, whiten="unit-variance")

# %%
Ysklearn = transformer.fit_transform(X.T).T

# %%
10 * np.log10(CalculateSINR(Ysklearn, S)[0])
# Out:
# 27.928226437260065
