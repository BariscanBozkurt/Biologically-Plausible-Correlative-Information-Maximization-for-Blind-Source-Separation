# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from WSMBSS import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.6
N = 500000
NumberofSources = 5
NumberofMixtures = 10

M = NumberofMixtures
r = NumberofSources

SNR = 30  # dB
NoiseAmp = 10 ** (-SNR / 20)  # * np.sqrt(NumberofSources)

S = generate_correlated_copula_sources(
    rho=rho,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=False,
)
S = 2 * S - 1
INPUT_STD = 0.5
A1 = np.random.standard_normal(size=(NumberofMixtures, NumberofSources))
X1 = A1 @ S
A2 = A1.copy()
for M in range(A1.shape[0]):
    stdx = np.std(X1[M, :])
    A2[M, :] = A2[M, :] / stdx * INPUT_STD
X2 = A2 @ S
X = (INPUT_STD * (X1 / X1.std(1)[:,np.newaxis]))
X = X1.copy()
A = A2.copy()

SNR = 30
Xnoisy, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))

X = (INPUT_STD * (Xnoisy / Xnoisy.std(1)[:,np.newaxis]))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.270 & 0.214 & -0.143 & 0.653 & 0.339 & \\
#  0.587 & 0.154 & -0.528 & 0.182 & 0.531 & \\
#  0.088 & 0.522 & -0.476 & 0.911 & -0.654 & \\
#  0.535 & 0.413 & -0.236 & -0.255 & 0.497 & \\
#  0.270 & -0.514 & 0.046 & -0.417 & -0.357 & \\
#  -0.440 & -0.230 & -0.175 & -0.365 & 0.625 & \\
#  0.466 & -0.136 & 0.248 & -0.806 & 0.850 & \\
#  -0.033 & 0.683 & -0.559 & 0.656 & 0.139 & \\
#  -0.274 & 0.127 & -0.264 & -0.127 & -0.598 & \\
#  0.655 & 0.316 & -0.212 & -0.006 & 0.270 & \\
# \end{bmatrix}$
# Input SNR is : 30.00290994297699

# %%
print(np.linalg.norm(X - X2))
X - X2
# Out:
# 35.352735699585644
# array([[ 0.02509877, -0.02776756, -0.03041884, ...,  0.0032361 ,
#         -0.00088473,  0.00530095],
#        [-0.00354738, -0.00010629, -0.02619151, ..., -0.01034861,
#         -0.05540537,  0.01141348],
#        [-0.01658204,  0.01337762, -0.00549296, ..., -0.00729128,
#         -0.01946672, -0.01215398],
#        ...,
#        [ 0.00645816, -0.00718851,  0.01841048, ..., -0.03251288,
#         -0.0003165 ,  0.00803783],
#        [ 0.00465129, -0.00319435,  0.01616583, ..., -0.01009367,
#          0.00098983, -0.01239592],
#        [ 0.01229924, -0.01474715,  0.00248043, ...,  0.01306414,
#         -0.00813204,  0.0015557 ]])

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
if rho > 0.4:
    gamma_start = 0.3
    gamma_stop = 1e-3
else:
    gamma_start = 0.6
    gamma_stop = 1e-3

gammaM_start = [gamma_start, gamma_start]
gammaM_stop = [gamma_stop, gamma_stop]
gammaW_start = [gamma_start, gamma_start]
gammaW_stop = [gamma_stop, gamma_stop]

OUTPUT_COMP_TOL = 1e-6
MAX_OUT_ITERATIONS = 3000
LayerGains = [1, 1]
LayerMinimumGains = [0.2, 0.2]
LayerMaximumGains = [1e6, 5]
WScalings = [0.005, 0.005]
GamScalings = [2, 1]
zeta = 5 * 1e-5
beta = 0.5
muD = [1.125, 0.2]

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = s_dim
samples = S.shape[1]
W_HX = np.eye(h_dim, x_dim)
W_YH = np.eye(s_dim, h_dim)

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
debug_iteration_point = 25000
modelWSM = OnlineWSMBSS(
    s_dim=s_dim,
    x_dim=x_dim,
    h_dim=h_dim,
    gammaM_start=gammaM_start,
    gammaM_stop=gammaM_stop,
    gammaW_start=gammaW_start,
    gammaW_stop=gammaW_stop,
    beta=beta,
    zeta=zeta,
    muD=muD,
    WScalings=WScalings,
    GamScalings=GamScalings,
    W_HX=W_HX,
    W_YH=W_YH,
    DScalings=LayerGains,
    LayerMinimumGains=LayerMinimumGains,
    LayerMaximumGains=LayerMaximumGains,
    neural_OUTPUT_COMP_TOL=OUTPUT_COMP_TOL,
    set_ground_truth=True,
    S=S,
    A=A,
)

# %%
modelWSM.fit_batch_antisparse(
    X,
    n_epochs=1,
    neural_dynamic_iterations=500,
    neural_lr_start=0.75,
    neural_lr_stop=0.05,
    neural_fast_start = True,
    synaptic_lr_decay_divider=1,
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 500000/500000 [03:13<00:00, 2578.19it/s]

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    modelWSM.SNR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = modelWSM.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [14.63497824 12.62502934 19.43107819 21.56910905 17.29417351]
#
# Overall SINR : 15.92815675307001

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
