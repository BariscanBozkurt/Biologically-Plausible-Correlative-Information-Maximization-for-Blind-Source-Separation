# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from WSMBSS import *
from numba import njit
from IPython import display
import pylab as pl
import warnings
warnings.filterwarnings("ignore")
# np.random.seed(874)
# %load_ext autoreload
# %autoreload 2
notebook_name = 'Nonnegative_Sparse'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
NumberofSources = 5
NumberofMixtures = 10
N = 5*1e5
S = 2*np.random.uniform(size = (NumberofSources,int(N)))-1
S = ProjectRowstoL1NormBall(S.T).T
S = S*(S>=0)

INPUT_STD = 0.5
A, X = WSM_Mixing_Scenario(S, NumberofMixtures, INPUT_STD)
SNR=30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))

plt.scatter(S[0,:], S[2,:])
plt.show()
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.086 & 1.097 & 1.231 & 2.637 & 1.036 & \\
#  0.031 & -2.005 & 0.945 & 1.503 & 1.062 & \\
#  1.820 & -0.533 & -0.710 & -0.227 & -2.051 & \\
#  0.053 & -1.655 & -2.223 & -0.184 & 1.048 & \\
#  1.257 & -0.481 & 0.564 & 1.844 & -1.669 & \\
#  0.063 & -1.261 & 1.963 & -0.749 & 1.516 & \\
#  1.947 & 1.912 & 0.870 & 1.262 & 1.645 & \\
#  0.833 & -1.616 & 0.328 & 2.218 & 0.368 & \\
#  2.117 & -0.409 & -0.590 & -1.502 & 0.966 & \\
#  -1.114 & -2.274 & -0.861 & -0.262 & 1.298 & \\
# \end{bmatrix}$
# Input SNR is : 30.004044885208444

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
MUS = 0.25

gammaM_start = [MUS, MUS]
gammaM_stop = [1e-3, 1e-3]
gammaW_start = [MUS, MUS]
gammaW_stop = [1e-3, 1e-3]

OUTPUT_COMP_TOL = 1e-5
MAX_OUT_ITERATIONS= 3000
LayerGains = [8,1]
LayerMinimumGains = [1e-6,1]
LayerMaximumGains = [1e6,1.001]
WScalings = [0.0033,0.0033]
GamScalings = [0.02,0.02]
zeta = 1e-4
beta = 0.5
muD = [20, 1e-2]

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = s_dim
samples = S.shape[1]

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
debug_iteration_point = 25000

model = OnlineWSMBSS(s_dim = s_dim, x_dim = x_dim, h_dim = h_dim, 
                     gammaM_start = gammaM_start, gammaM_stop = gammaM_stop, 
                     gammaW_start = gammaW_start, gammaW_stop = gammaW_stop,
                     beta = beta, zeta = zeta, 
                     muD = muD,WScalings = WScalings,
                     DScalings = LayerGains, LayerMinimumGains = LayerMinimumGains,
                     LayerMaximumGains = LayerMaximumGains,neural_OUTPUT_COMP_TOL = OUTPUT_COMP_TOL,
                     set_ground_truth = True, S = S, A = A)

model.fit_batch_nnsparse(X, n_epochs = 1, neural_lr_start = 0.5, neural_lr_stop = 0.2,
                         debug_iteration_point = debug_iteration_point, 
                         plot_in_jupyter = True)
# Out:
# 100%|██████████| 500000/500000 [04:36<00:00, 1808.28it/s]

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(model.SNR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Szeromean = S - S.mean(axis = 1).reshape(-1,1)
Wf = model.compute_overall_mapping(return_mapping = True)
Y_ = Wf @ X
Yzeromean = Y_ - Y_.mean(axis = 1).reshape(-1,1)
Y_ = model.signed_and_permutation_corrected_sources(Szeromean,Yzeromean)
coef_ = ((Y_ * Szeromean).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Szeromean, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, Szeromean)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [24.10320939 27.1597887  24.78843752 23.59927257 27.76262285]
#
# Overall SINR : 25.169390985949672

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
import mir_eval

# %%
S.shape, Y_.shape
# Out:
# ((5, 500000), (5, 500000))

# %%
mir_eval.separation.bss_eval_sources(S, Y_,
                     compute_permutation=True)
# Out:
# (array([22.19465425, 23.85025734, 22.60141669, 21.83563151, 24.13433978]),
#  array([23.20313707, 25.23879062, 23.96197265, 22.65849726, 25.97518667]),
#  array([29.0510227 , 29.49130166, 28.32203514, 29.48860665, 28.76092415]),
#  array([0, 1, 2, 3, 4]))
