# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from WSMBSS import *
from general_utils import *
from visualization_utils import *
from polytope_utils import *

import warnings

warnings.filterwarnings("ignore")
# np.random.seed(100)
# %load_ext autoreload
# %autoreload 2
notebook_name = "Nonnegative_Antisparse_Copula"

# %%
seed_ = np.random.randint(50000)
# seed_ = 22168
# seed_ = 484
seed_ = 14595
np.random.seed(seed_)
print('Seed is : {}'.format(seed_))
# Out:
# Seed is : 14595

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
# rho = 0.6
# N = 500000
# NumberofSources = 5
# NumberofMixtures = 10

# # NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)

# S = generate_correlated_copula_sources(
#     rho=rho,
#     df=4,
#     n_sources=NumberofSources,
#     size_sources=N,
#     decreasing_correlation=False,
# )

# INPUT_STD = 0.28
# # A, X = WSM_Mixing_Scenario(S, NumberofMixtures, INPUT_STD)
# A1 = np.random.standard_normal(size=(NumberofMixtures, NumberofSources))
# X1 = A1 @ S
# A2 = A1.copy()
# for M in range(A1.shape[0]):
#     stdx = np.std(X1[M, :])
#     A2[M, :] = A2[M, :] / stdx * INPUT_STD
# X2 = A2 @ S
# X = (INPUT_STD * (X1 / X1.std(1)[:,np.newaxis]))
# X = X1.copy()
# A = A2.copy()
# SNR = 30
# X, NoisePart = addWGN(X, SNR, return_noise=True)

# SNRinp = 10 * np.log10(
#     np.sum(np.mean((X - NoisePart) ** 2, axis=1))
#     / np.sum(np.mean(NoisePart**2, axis=1))
# )
# print("The following is the mixture matrix A")
# display_matrix(A)
# print("Input SNR is : {}".format(SNRinp))
# X = (INPUT_STD * (X / X.std(1)[:,np.newaxis]))

rho = 0.5
N = 500000
NumberofSources = 5
NumberofMixtures = 10

# NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)

S = generate_correlated_copula_sources(
    rho=rho,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=False,
)

INPUT_STD = 0.28
# A, X = WSM_Mixing_Scenario(S, NumberofMixtures, INPUT_STD)
A1 = np.random.standard_normal(size=(NumberofMixtures, NumberofSources))
X1 = A1 @ S
A2 = A1.copy()
for M in range(A1.shape[0]):
    stdx = np.std(X1[M, :])
    A2[M, :] = A2[M, :] / stdx * INPUT_STD
X2 = A2 @ S
X = (INPUT_STD * (X1 / X1.std(1)[:,np.newaxis]))
X = X1.copy()
A = A2.copy()
SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
X = (INPUT_STD * (X / X.std(1)[:,np.newaxis]))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.288 & 0.912 & 0.190 & -0.092 & -0.727 & \\
#  0.640 & 0.020 & -0.604 & -0.743 & -0.024 & \\
#  -0.307 & -0.339 & -0.077 & -0.288 & -0.253 & \\
#  -0.093 & -0.798 & 0.373 & 0.376 & -0.599 & \\
#  0.873 & -0.222 & 0.021 & 0.470 & -0.795 & \\
#  -0.603 & -0.796 & 0.188 & 0.035 & 0.329 & \\
#  0.076 & 0.263 & 1.037 & -0.553 & -0.358 & \\
#  -0.081 & 0.730 & -0.701 & -0.220 & 0.717 & \\
#  0.307 & -0.905 & 0.230 & 0.066 & -0.491 & \\
#  -0.219 & -0.199 & -0.246 & -0.396 & -0.210 & \\
# \end{bmatrix}$
# Input SNR is : 29.99925812143489

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
if rho > 0.4:
    gamma_start = 0.05
    gamma_stop = 5 * 1e-4
else:
    gamma_start = 0.1
    gamma_stop = 1e-3

gammaM_start = [gamma_start, gamma_start]
gammaM_stop = [gamma_stop, gamma_stop]
gammaW_start = [gamma_start, gamma_start]
gammaW_stop = [gamma_stop, gamma_stop]

OUTPUT_COMP_TOL = 1e-7
MAX_OUT_ITERATIONS = 3000
LayerGains = [1, 1]
LayerMinimumGains = np.array([1e-3, 1e-3])
LayerMaximumGains = np.array([1e6, 20])
WScalings = [0.0033, 0.0033]
GamScalings = [2, 1]
zeta = 1 * 1e-5
beta = 0.5
muD = np.array([1.0, 1e-2])

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = s_dim
samples = S.shape[1]
W_HX = np.eye(h_dim, x_dim)
W_YH = np.eye(s_dim, h_dim)

neural_dynamic_iterations = 500
neural_lr_start = 0.75
neural_lr_stop = 0.05
neural_loop_lr_rule = "divide_by_slow_loop_index"
neural_lr_decay_multiplier = 0.005
hidden_layer_gain=100
neural_OUTPUT_COMP_TOL = OUTPUT_COMP_TOL

synaptic_lr_decay_divider=1
clip_gain_gradients=True
gain_grads_clipping_multiplier = 1

# %% [raw]
# # debug_iteration_point = 25000
# # modelWSM = OnlineWSMBSS(
# #     s_dim=s_dim,
# #     x_dim=x_dim,
# #     h_dim=h_dim,
# #     gammaM_start=gammaM_start,
# #     gammaM_stop=gammaM_stop,
# #     gammaW_start=gammaW_start,
# #     gammaW_stop=gammaW_stop,
# #     beta=beta,
# #     zeta=zeta,
# #     muD=muD,
# #     WScalings=WScalings,
# #     GamScalings=GamScalings,
# #     W_HX=W_HX,
# #     W_YH=W_YH,
# #     DScalings=LayerGains,
# #     LayerMinimumGains=LayerMinimumGains,
# #     LayerMaximumGains=LayerMaximumGains,
# #     neural_OUTPUT_COMP_TOL=OUTPUT_COMP_TOL,
# #     set_ground_truth=True,
# #     S=S,
# #     A=A,
# # )
#
# # modelWSM.fit_batch_nnantisparse(
# #     X,
# #     n_epochs=1,
# #     neural_dynamic_iterations=500,
# #     neural_lr_start=0.75,
# #     neural_lr_stop=0.05,
# #     synaptic_lr_rule="divide_by_log_index",
# #     neural_loop_lr_rule="divide_by_slow_loop_index",
# #     synaptic_lr_decay_divider=1,
# #     neural_lr_decay_multiplier=0.005,
# #     hidden_layer_gain=100,
# #     clip_gain_gradients=True,
# #     gain_grads_clipping_multiplier = 1,
# #     use_newton_steps_for_gains = False,
# #     shuffle=True,
# #     debug_iteration_point=debug_iteration_point,
# #     plot_in_jupyter=True,
# # )

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
debug_iteration_point = 25000
modelWSM = OnlineWSMBSS(
    s_dim=s_dim,
    x_dim=x_dim,
    h_dim=h_dim,
    gammaM_start=gammaM_start,
    gammaM_stop=gammaM_stop,
    gammaW_start=gammaW_start,
    gammaW_stop=gammaW_stop,
    beta=beta,
    zeta=zeta,
    muD=muD,
    WScalings=WScalings,
    GamScalings=GamScalings,
    W_HX=W_HX,
    W_YH=W_YH,
    DScalings=LayerGains,
    LayerMinimumGains=LayerMinimumGains,
    LayerMaximumGains=LayerMaximumGains,
    neural_OUTPUT_COMP_TOL=OUTPUT_COMP_TOL,
    set_ground_truth=True,
    S=S,
    A=A,
)

modelWSM.fit_batch_nnantisparse(
    X,
    n_epochs=1,
    neural_dynamic_iterations=500,
    neural_lr_start=0.75,
    neural_lr_stop=0.05,
    synaptic_lr_rule="divide_by_log_index",
    neural_loop_lr_rule="divide_by_slow_loop_index",
    synaptic_lr_decay_divider=1,
    neural_lr_decay_multiplier=0.005,
    hidden_layer_gain=100,
    clip_gain_gradients=True,
    gain_grads_clipping_multiplier = 1,
    use_newton_steps_for_gains = False,
    shuffle=True,
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 500000/500000 [21:12<00:00, 392.82it/s]

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    modelWSM.SNR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = modelWSM.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [21.35073119 28.20525886  6.2140613  31.11721486 24.01690621]
#
# Overall SINR : 25.43272590076021

# %%
Wf = modelWSM.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = Y[[3,4,2,0,1]]
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [6.46722272 6.0363951  5.4802872  5.73304771 5.31505936]
#
# Overall SINR : 23.407157529930966

# %%
np.abs(outer_prod_broadcasting(Y.T, S.T).sum(axis=0)) / (np.linalg.norm(S, axis=1) * np.linalg.norm(Y, axis=1))
# Out:
# array([[0.85720272, 1.13945572, 0.91773814, 1.01879603, 0.86245834],
#        [0.87372977, 0.88057205, 0.81193758, 0.89274785, 0.73662378],
#        [0.78860529, 0.92022436, 0.84668738, 0.94375865, 0.92446112],
#        [0.73947388, 0.80451344, 0.90258991, 0.87797355, 0.71455891],
#        [0.86368009, 0.98836944, 0.94169456, 1.1898738 , 0.86840399]])

# %%
np.argmax(
        np.abs(outer_prod_broadcasting(Y.T, S.T).sum(axis=0))
        / (np.linalg.norm(S, axis=1) * np.linalg.norm(Y, axis=1)),
        axis=0,
    )
# Out:
# array([1, 0, 4, 4, 2])

# %%
np.corrcoef(S, Y)[:5,:5] - np.corrcoef(S)
# Out:
# array([[-2.22044605e-16,  3.88578059e-16,  5.55111512e-16,
#          2.22044605e-16,  2.77555756e-16],
#        [ 3.88578059e-16,  0.00000000e+00,  5.55111512e-16,
#          1.11022302e-16, -1.11022302e-16],
#        [ 4.44089210e-16,  6.10622664e-16, -2.22044605e-16,
#          0.00000000e+00, -1.66533454e-16],
#        [ 2.77555756e-16,  1.11022302e-16,  0.00000000e+00,
#          0.00000000e+00,  1.11022302e-16],
#        [ 2.22044605e-16,  0.00000000e+00, -1.66533454e-16,
#          1.11022302e-16,  2.22044605e-16]])

# %%
np.corrcoef(Y)
# Out:
# array([[1.        , 0.51247946, 0.50135596, 0.31184102, 0.43676478],
#        [0.51247946, 1.        , 0.34029912, 0.49525308, 0.42059931],
#        [0.50135596, 0.34029912, 1.        , 0.33745564, 0.44492471],
#        [0.31184102, 0.49525308, 0.33745564, 1.        , 0.53605729],
#        [0.43676478, 0.42059931, 0.44492471, 0.53605729, 1.        ]])

# %%
display_matrix(np.corrcoef(S, Y))
# Out:
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.468 & 0.472 & 0.467 & 0.469 & 0.445 & 0.986 & 0.423 & 0.528 & 0.453 & \\
#  0.468 & 1.000 & 0.469 & 0.467 & 0.470 & 0.998 & 0.534 & 0.499 & 0.369 & 0.465 & \\
#  0.472 & 0.469 & 1.000 & 0.470 & 0.469 & 0.417 & 0.445 & 0.405 & 0.981 & 0.488 & \\
#  0.467 & 0.467 & 0.470 & 1.000 & 0.469 & 0.440 & 0.436 & 0.441 & 0.520 & 0.998 & \\
#  0.469 & 0.470 & 0.469 & 0.469 & 1.000 & 0.466 & 0.377 & 0.993 & 0.412 & 0.473 & \\
#  0.445 & 0.998 & 0.417 & 0.440 & 0.466 & 1.000 & 0.512 & 0.501 & 0.312 & 0.437 & \\
#  0.986 & 0.534 & 0.445 & 0.436 & 0.377 & 0.512 & 1.000 & 0.340 & 0.495 & 0.421 & \\
#  0.423 & 0.499 & 0.405 & 0.441 & 0.993 & 0.501 & 0.340 & 1.000 & 0.337 & 0.445 & \\
#  0.528 & 0.369 & 0.981 & 0.520 & 0.412 & 0.312 & 0.495 & 0.337 & 1.000 & 0.536 & \\
#  0.453 & 0.465 & 0.488 & 0.998 & 0.473 & 0.437 & 0.421 & 0.445 & 0.536 & 1.000 & \\
# \end{bmatrix}$

# %%
np.argmax(np.corrcoef(S, Y)[5:,:5], axis = 0) #- np.corrcoef(S, Y)[5:,5:]
# Out:
# array([1, 0, 3, 4, 2])

# %%
np.argmax(np.corrcoef(Y, S)[:5,5:], axis = 0)
# Out:
# array([1, 0, 3, 4, 2])

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
