# %% [markdown]
# # Import Required Libraries

# %%
import sys
sys.path.append("../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import *
from polytope_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Sparse"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(
    rho=0.5,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)
S = 2 * S - 1

# print("The following is the correlation matrix of sources")
# display_matrix(np.corrcoef(S))

plt.scatter(S[0, :], S[2, :])


# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.180 & -0.218 & 1.326 & 0.135 & -1.526 & \\
#  0.058 & 1.010 & 0.838 & -0.576 & -1.299 & \\
#  0.646 & -2.076 & -0.110 & -2.101 & 0.254 & \\
#  -0.356 & -0.361 & 1.354 & 0.132 & 0.590 & \\
#  1.025 & 1.251 & -1.060 & 0.113 & -0.338 & \\
#  2.093 & 0.598 & 0.752 & 1.268 & 0.203 & \\
#  0.964 & 0.416 & -1.564 & -0.464 & -1.229 & \\
#  -1.628 & -0.699 & 0.305 & 0.784 & 1.311 & \\
#  1.199 & -0.856 & -0.170 & 1.374 & -1.251 & \\
#  1.317 & 0.836 & 0.925 & 0.227 & -0.311 & \\
# \end{bmatrix}$
# Input SNR is : 30.001192525349506

# %%
dim = 5
signed_dims = np.array([0, 1, 2, 3, 4])
nn_dims = np.array([])
sparse_dims_list = []
(Apoly, bpoly), V = generate_practical_polytope(dim, signed_dims, nn_dims, sparse_dims_list)
Apoly, bpoly = Apoly.astype(np.float64), bpoly.astype(np.float64)

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
lambday = 1 - 1e-1 / 10
lambdae = 1 - 1e-1 / 10
s_dim = S.shape[0]
x_dim = X.shape[0]

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 1000 * np.eye(s_dim)

debug_iteration_point = 5000
model = OnlineCorInfoMaxCanonical(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=30 * 1e-3,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=True,
    S=S,
    A=A,
)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch(
        X=X,
        Apoly = Apoly,
        bpoly = bpoly,
        n_epochs=1,
        neural_dynamic_iterations=500,
        plot_in_jupyter=True,
        neural_lr_start=0.9,
        neural_lr_stop=0.001,
        debug_iteration_point=debug_iteration_point,
        shuffle=True,
    )
print("Algorithm took %f sec." % (t.interval))
# Out:
# 100%|██████████| 500000/500000 [14:03<00:00, 592.92it/s]
# Algorithm took 843.454186 sec.

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    model.SIR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

print("Final SINR: {}".format(np.array(model.SIR_list[-1])))
# Out:
# Final SINR: 22.404427258198382

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [23.5641968  22.62310845 21.62485004 20.05925251 26.98170276]
#
# Overall SINR : 22.404427258198382

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
