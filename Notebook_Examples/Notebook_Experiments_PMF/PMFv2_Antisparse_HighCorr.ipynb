# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
Sgt = generate_correlated_copula_sources(
    rho=0.8,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)

Sgt = 2 * Sgt - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures, NumberofSources)
Y = np.dot(Agt, Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((Y - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.775 & 0.604 & 0.483 & 0.374 & \\
#  0.775 & 1.000 & 0.767 & 0.603 & 0.464 & \\
#  0.604 & 0.767 & 1.000 & 0.761 & 0.590 & \\
#  0.483 & 0.603 & 0.761 & 1.000 & 0.767 & \\
#  0.374 & 0.464 & 0.590 & 0.767 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.078 & -0.556 & -1.601 & -0.276 & -0.425 & \\
#  1.035 & -0.221 & 0.312 & 1.963 & -0.123 & \\
#  -0.150 & 0.073 & -0.609 & 0.487 & -0.689 & \\
#  -0.345 & -0.836 & 0.297 & -0.111 & 0.840 & \\
#  0.434 & 0.574 & 1.482 & -0.553 & -0.574 & \\
#  -0.705 & -0.580 & -0.869 & -0.595 & -1.044 & \\
#  1.003 & -0.459 & 0.899 & 0.262 & -1.458 & \\
#  0.615 & -1.167 & -0.836 & -0.406 & -1.253 & \\
#  -0.450 & 0.397 & -0.676 & -0.135 & -0.478 & \\
#  -1.367 & -2.342 & 0.207 & 0.269 & -0.697 & \\
# \end{bmatrix}$
# Input SNR is : 30.010515587979146

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    Y[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 25000
model = PMFv2(s_dim=s_dim, y_dim=y_dim, set_ground_truth=True, Sgt=Sgt, Agt=Agt)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_antisparse(
    Y,
    n_iterations=100000,
    step_size_scale=100,
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 100000/100000 [00:59<00:00, 1671.38it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Spmf = model.S
Spmf = signed_and_permutation_corrected_sources(Sgt, Spmf)
coef_ = ((Spmf * Sgt).sum(axis=1) / (Spmf * Spmf).sum(axis=1)).reshape(-1, 1)
Spmf = coef_ * Spmf

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Spmf)))

SINR = 10 * np.log10(CalculateSINRjit(Spmf, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [25.25243284 26.30927506 28.27641783 25.74811829 29.68563504]
#
# Overall SINR : 26.750563265902056

# %%
WfPMF = np.linalg.pinv(model.H)
Spmf = WfPMF @ Y
Spmf = signed_and_permutation_corrected_sources(Sgt, Spmf)
coef_ = ((Spmf * Sgt).sum(axis=1) / (Spmf * Spmf).sum(axis=1)).reshape(-1, 1)
Spmf = coef_ * Spmf

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Spmf)))

SINR = 10 * np.log10(CalculateSINRjit(Spmf, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [25.24563272 26.30897694 28.2776411  25.74638463 29.68157202]
#
# Overall SINR : 26.74787535410288

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Spmf[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
