# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Nonnegative_Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
Sgt = generate_correlated_copula_sources(
    rho=0.7,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)

print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures, NumberofSources)
Y = np.dot(Agt, Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((Y - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.670 & 0.449 & 0.319 & 0.219 & \\
#  0.670 & 1.000 & 0.675 & 0.466 & 0.321 & \\
#  0.449 & 0.675 & 1.000 & 0.667 & 0.460 & \\
#  0.319 & 0.466 & 0.667 & 1.000 & 0.667 & \\
#  0.219 & 0.321 & 0.460 & 0.667 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -1.423 & -0.814 & 1.372 & -0.774 & -0.147 & \\
#  0.192 & 1.336 & 0.252 & 1.118 & -0.618 & \\
#  -1.728 & -0.554 & -0.445 & 0.700 & -0.310 & \\
#  0.700 & 0.132 & 1.001 & 0.212 & -0.264 & \\
#  0.080 & 0.554 & -1.034 & 0.682 & 0.831 & \\
#  -0.277 & 1.166 & 0.262 & -1.011 & -0.591 & \\
#  0.478 & 0.580 & 0.059 & -0.922 & -0.606 & \\
#  -0.890 & -1.140 & 1.102 & 0.192 & 0.466 & \\
#  -0.162 & -0.791 & -1.292 & 0.129 & -0.449 & \\
#  -2.234 & 1.551 & -0.608 & -1.469 & -0.549 & \\
# \end{bmatrix}$
# Input SNR is : 29.9820606294527

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    Y[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 25000
model = PMFv2(s_dim=s_dim, y_dim=y_dim, set_ground_truth=True, Sgt=Sgt, Agt=Agt)

# %% [markdown]
# # Run PMF Algorithm on Mixture Signals

# %%
model.fit_batch_nnantisparse(
    Y,
    n_iterations=100000,
    step_size_scale=100,
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 100000/100000 [01:07<00:00, 1481.04it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Spmf = model.S
Spmf = signed_and_permutation_corrected_sources(Sgt, Spmf)
coef_ = ((Spmf * Sgt).sum(axis=1) / (Spmf * Spmf).sum(axis=1)).reshape(-1, 1)
Spmf = coef_ * Spmf

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Spmf)))

SINR = 10 * np.log10(CalculateSINRjit(Spmf, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [30.90481716 29.28519109 30.72584159 28.78128405 26.70155591]
#
# Overall SINR : 29.041027813481442

# %%
WfPMF = model.W
Spmf = WfPMF @ Y
Spmf = signed_and_permutation_corrected_sources(Sgt, Spmf)
coef_ = ((Spmf * Sgt).sum(axis=1) / (Spmf * Spmf).sum(axis=1)).reshape(-1, 1)
Spmf = coef_ * Spmf

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Spmf)))

SINR = 10 * np.log10(CalculateSINRjit(Spmf, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [30.87501952 29.24803325 30.69108076 28.73785275 26.66356776]
#
# Overall SINR : 29.00433840811363

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Spmf[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
