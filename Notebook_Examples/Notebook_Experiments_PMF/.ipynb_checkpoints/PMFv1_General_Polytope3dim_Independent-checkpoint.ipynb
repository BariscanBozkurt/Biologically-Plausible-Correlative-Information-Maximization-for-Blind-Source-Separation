# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from polytope_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'General_Polytope'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
dim = 3
N = 5000
NumberofSources = dim
NumberofMixtures = 6

signed_dims = np.array([0,1])
nn_dims = np.array([2])
sparse_dims_list = [np.array([0,1]),np.array([1,2])]
(A,b), V = generate_practical_polytope(dim, signed_dims, nn_dims, sparse_dims_list)
Sgt = generate_uniform_points_in_polytope(V, N)

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures,NumberofSources)
Y = np.dot(Agt,Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((Y - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.382 & 0.530 & -0.075 & \\
#  -0.053 & 2.070 & 0.758 & \\
#  1.358 & -0.675 & -0.390 & \\
#  -0.787 & 0.004 & 0.843 & \\
#  -0.218 & -0.231 & 0.342 & \\
#  1.831 & 0.009 & -0.522 & \\
# \end{bmatrix}$
# Input SNR is : 29.994801012676042

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Y[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 5000
model = PMF(s_dim = s_dim, y_dim = y_dim,
            set_ground_truth = True, Sgt = Sgt, Agt = Agt)

# %% [markdown]
# # Run PMF Algorithm on Mixture Signals

# %%
model.fit_batch_general_polytope(Y, n_iterations = 15000,
                                 signed_dims = signed_dims, nn_dims = nn_dims, 
                                 sparse_dims_list = sparse_dims_list,
                                 Lt = 50, lambda_ = 10, tau = 1, 
                                 debug_iteration_point = debug_iteration_point,
                                 plot_in_jupyter = True)
# Out:
# 100%|██████████| 15000/15000 [01:45<00:00, 142.33it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y = model.S
Y_ = signed_and_permutation_corrected_sources(Sgt,Y)
coef_ = ((Y_ * Sgt).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [31.37658433 28.17121775 25.71831693]
#
# Overall SINR : 27.833610234331395

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
