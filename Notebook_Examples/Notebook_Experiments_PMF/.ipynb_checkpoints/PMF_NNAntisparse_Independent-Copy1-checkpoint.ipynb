# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
Sgt = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = True)

Sgt = 2 * Sgt - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures,NumberofSources)
Y = np.dot(Agt,Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((Y - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.006 & -0.012 & 0.003 & 0.010 & \\
#  -0.006 & 1.000 & -0.009 & -0.014 & -0.011 & \\
#  -0.012 & -0.009 & 1.000 & 0.014 & -0.003 & \\
#  0.003 & -0.014 & 0.014 & 1.000 & 0.025 & \\
#  0.010 & -0.011 & -0.003 & 0.025 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.176 & -1.256 & 0.435 & 1.070 & 0.501 & \\
#  0.076 & 1.059 & 0.864 & -0.166 & -2.033 & \\
#  -0.699 & -0.393 & -1.362 & -0.389 & 0.555 & \\
#  -0.461 & 0.200 & 0.440 & 0.019 & -0.274 & \\
#  -0.699 & 1.571 & 0.486 & -0.071 & -1.795 & \\
#  1.377 & 2.068 & -0.723 & 0.294 & -0.148 & \\
#  -0.677 & -2.047 & -0.937 & 0.990 & 1.469 & \\
#  -1.467 & 0.532 & 0.406 & 0.183 & -0.463 & \\
#  1.771 & -1.934 & 0.673 & 0.329 & 2.065 & \\
#  -1.568 & -0.067 & -0.546 & -0.496 & -0.464 & \\
# \end{bmatrix}$
# Input SNR is : 30.000606124948092

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 2000
model = PMFv1(s_dim = s_dim, y_dim = y_dim,
                set_ground_truth = True, Sgt = Sgt, Agt = Agt)
model.fit_batch_antisparse(Y, n_iterations = 50000,
                           Lt = 50, lambda_ = 28, tau = 1e-10, 
                           debug_iteration_point = debug_iteration_point,
                           plot_in_jupyter = True)
# Out:
# 100%|██████████| 50000/50000 [01:35<00:00, 520.91it/s]

# %%
x_dim = Y.shape[0]
s_dim = Sgt.shape[0]
H = np.random.randn(x_dim, s_dim)
U,_,V = np.linalg.svd(Y,full_matrices=False)
S = V[0:s_dim,:]
H = U[:,:s_dim]
# H = np.eye(x_dim, s_dim)
Identity = np.eye(s_dim)
F = Identity.copy()
q = 1
Lt = 50
lambda_ = 28
tau = 1e-10

# %%
n_iterations = 10000

r = NumberofSources
nlamda = lambda_
dif=S

for k in tqdm(range(n_iterations)):

    Sprev=S.copy()
    S=S +((q-1)/((1+math.sqrt(1+4*q*q))/2))*(dif)
    S = S - (np.dot(H.T,(np.dot(H,S) - Y))/(Lt*np.linalg.norm(np.transpose(H)@H, 2)))
    q = (1+math.sqrt(1+4*q*q))/2
    S = np.clip(S, -1, 1)
    dif = S - Sprev


    H = np.dot(np.dot(Y,S.T),np.linalg.inv(np.dot(S,S.T)+nlamda*F))

    F = np.linalg.inv(np.dot(np.transpose(H),H)+tau*np.eye(r))
# Out:
# 100%|██████████| 10000/10000 [00:08<00:00, 1151.55it/s]

# %%
# Wf = model.W
Ypmf = S
Y_ = signed_and_permutation_corrected_sources(Sgt - Sgt.mean(axis = 1, keepdims=True),Ypmf - Ypmf.mean(axis = 1, keepdims=True))
coef_ = ((Y_ * (Sgt - Sgt.mean(axis = 1, keepdims=True))).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(Sgt - Sgt.mean(axis = 1, keepdims=True), Y_)))

SINR = 10*np.log10(CalculateSINR(Y_, (Sgt - Sgt.mean(axis = 1, keepdims=True)))[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [29.98292638 29.2269644  31.60875633 29.10916437 29.29466389]
#
# Overall SINR : 29.747783990760688

# %%
CalculateSIR(Agt, np.linalg.pinv(H))
# Out:
# (43.51236257947772, 5)

# %%
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Ypmf[:,0:100], title = 'Mixture Signals', figsize = (15,9), colorcode = None)

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Y[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %%
N = 2000
NumberofSources = 10
NumberofMixtures = 20
Sgt = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)

# print("The following is the correlation matrix of sources")
# display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures,NumberofSources)
Y = np.dot(Agt,Sgt)

SNR = 100
Y, NoisePart = addWGN(Y, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((Y - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
# print("The following is the mixture matrix A")
# display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# Input SNR is : 99.97488198297022

# %%
x_dim = Y.shape[0]
s_dim = Sgt.shape[0]
H = np.random.randn(x_dim, s_dim)
U,_,V = np.linalg.svd(Y,full_matrices=False)
S = V[0:s_dim,:]
H = U[:,:s_dim]
# H = np.eye(x_dim, s_dim)
Identity = np.eye(s_dim)
F = Identity.copy()
q = 1
Lt = 30
lambda_ = 30
tau = 1e-10

# %%
n_iterations = 10000

r = NumberofSources
nlamda = lambda_
dif=S*0
kk = 0
nk = 0
for k in tqdm(range(n_iterations)):

    Sprev=S.copy()
    S=S +((q-1)/((1+math.sqrt(1+4*q*q))/2))*(dif)
    S = S - (np.dot(H.T,(np.dot(H,S) - Y))/(Lt*np.linalg.norm(np.transpose(H)@H, 2)))
    q = (1+math.sqrt(1+4*q*q))/2
    S = np.clip(S, 0, 1)
    dif = S - Sprev


    H = np.dot(np.dot(Y,S.T),np.linalg.inv(np.dot(S,S.T)+nlamda*F))

    F = np.linalg.inv(np.dot(np.transpose(H),H)+tau*np.eye(r))
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 2573.90it/s]

# %%
CalculateSIR(Agt, np.linalg.pinv(H))
# Out:
# (-7.391451804346733, 2)

# %%
# Wf = model.W
Ypmf = S
Y_ = signed_and_permutation_corrected_sources(Sgt - Sgt.mean(axis = 1, keepdims=True),Ypmf - Ypmf.mean(axis = 1, keepdims=True))
coef_ = ((Y_ * (Sgt - Sgt.mean(axis = 1, keepdims=True))).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(Sgt - Sgt.mean(axis = 1, keepdims=True), Y_)))

SINR = 10*np.log10(CalculateSINR(Y_, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [ 8.44082902  3.24712381  3.39327085  9.96951459  2.68889447  4.47193792
#  16.95374109  9.48672436  1.76918176 12.60143372]
#
# Overall SINR : 5.852359828465723

# %%
subplot_1D_signals(S[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
find_permutation_between_source_and_estimation(Sgt, )
# Out:
# array([0, 0, 0, 0, 0])

# %%
n_iterations = 1000
X = S.copy()
diff = S.copy()
for k in tqdm(range(n_iterations)):
    #### PMF Algorithm #################
    Sprev = S.copy()
    S = S + ((q-1)/((1+math.sqrt(1+4*q*q))/2))*(diff)
    S = S - H.T @ (H @ S - Y) / (Lt * np.linalg.norm(H.T @ H))
    q = (1 + math.sqrt(1 + 4 * q * q )) / 2
    S = np.clip(S, 0, 1)
    diff = S - Sprev
    H = Y @ S.T @ np.linalg.inv(S @ S.T + lambda_ * F)
    F = np.linalg.pinv(H.T @ H + tau * Identity)
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 2063.18it/s]

# %%
W = H.copy()
H = (S.T).copy()
r = NumberofSources
dif=H
for k in tqdm(range(n_iterations)):
    kk=kk+1

    iter = k
    nk=nk+1

    fastH=H.copy()
    H=self.H+((q-1)/((1+math.sqrt(1+4*q*q))/2))*(dif)
    H = H - np.transpose((np.dot(np.transpose(W),(np.dot(W,np.transpose(H)) - Y))/(self.Lt*np.linalg.norm(np.transpose(W)@W, 2))))
    q = (1+math.sqrt(1+4*q*q))/2
    H = np.clip(H, 0, 1)
    dif = H - fastH


    W = np.dot(np.dot(Y,H),np.linalg.inv(np.dot(np.transpose(H),H)+self.nlamda*F))

    F = np.linalg.inv(np.dot(np.transpose(W),W)+tau*np.eye(r))

# %%
# Wf = model.W
Y = S.copy()
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(Sgt, Y_)))

SINR = 10*np.log10(CalculateSINR(Y_, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [ 0.49394439  0.2293109  -0.20952318  0.3038404   0.00418052 -0.09411216
#  -0.06128077  0.0947975  -0.25230135  0.16185374]
#
# Overall SINR : 33.48470188178021

# %%
subplot_1D_signals(Ypmf[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
U,S,V = np.linalg.svd(X,full_matrices=False)
V[0:NumberofSources,:].shape
# Out:
# (5, 10000)

# %%
U[:,:NumberofSources].shape
# Out:
# (8, 5)

# %%
#---------------------------PMF---------------------------------
NumIterations=10000
R = NumberofSources
pmf2=pmf(X,R)   
pmf2.BoundMax=np.array([np.ones(R)])
pmf2.BoundMin=np.array([np.zeros(R)])
pmf2.SparseList=np.array([],dtype=object)
pmf2.SetGroundTruth(S.T)
pmf2.SetGroundTruthW(A)
pmf2.MaxIterations=1
pmf2.algorithm_iterations=1000
pmf2.step_size_rule='const'
pmf2.checklocalstationary=0
pmf2.detwindow=100
pmf2.algorithm_iterations=NumIterations
pmf2.Lt=30

# %%
M = NumberofMixtures
a = np.random.random(size=(M, R))
q, _ = np.linalg.qr(a)
q.shape
# Out:
# (8, 5)

# %%
pmf2.W = q
pmf2.noisy_general(checklocalstationary=0,verbose=1,HProjectionPeriod=1,tau=1e-10,nlamda=2.5, p=2)
# Out:
# 0

# %%
H = np.random.randn(x_dim, s_dim)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 200
model = PMF(s_dim = s_dim, x_dim = x_dim,
                set_ground_truth = True, Sgt = S, Agt = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_nnantisparse(X, Lt = 10, lambda_ = 2, tau = 1e-8, 
                             plot_in_jupyter = True)
# Out:
#   0%|          | 0/10000 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [7], in <module>
# ----> 1 model.fit_batch_nnantisparse(X, Lt = 10, lambda_ = 2, tau = 1e-8,
#       2                              plot_in_jupyter = True)
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/src/PMF.py:141, in PMF.fit_batch_nnantisparse(self, Y, n_iterations, Lt, lambda_, tau, debug_iteration_point, plot_in_jupyter)
#     139 if ((k % debug_iteration_point) == 0)  | (k == n_iterations - 1):
#     140     self.H = H
# --> 141     S_ = self.signed_and_permutation_corrected_sources(Sgt,S)
#     142     coef_ = ((S_ * S).sum(axis = 1) / (S_ * S_).sum(axis = 1)).reshape(-1,1)
#     143     S_ = coef_ * S_
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/src/BSSbase.py:133, in BSSBaseClass.signed_and_permutation_corrected_sources(self, S, Y)
#     123 def signed_and_permutation_corrected_sources(self,S,Y):
#     124     """_summary_
#     125
#     126     Args:
#    (...)
#     131         _type_: _description_
#     132     """
# --> 133     perm = self.find_permutation_between_source_and_estimation(S,Y)
#     134     return (np.sign((Y[perm,:] * S).sum(axis = 1))[:,np.newaxis]) * Y[perm,:]
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/src/BSSbase.py:120, in BSSBaseClass.find_permutation_between_source_and_estimation(self, S, Y)
#     113 """
#     114 S    : Original source matrix
#     115 Y    : Matrix of estimations of sources (after BSS or ICA algorithm)
#     116
#     117 return the permutation of the source seperation algorithm
#     118 """
#     119 # perm = np.argmax(np.abs(self.outer_prod_broadcasting(Y,S).sum(axis = 0))/(np.linalg.norm(S,axis = 0)*np.linalg.norm(Y,axis=0)), axis = 0)
# --> 120 perm = np.argmax(np.abs(self.outer_prod_broadcasting(Y.T,S.T).sum(axis = 0))/(np.linalg.norm(S,axis = 1)*np.linalg.norm(Y,axis=1)), axis = 0)
#     121 return perm
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~/.conda/envs/wsm/lib/python3.8/site-packages/numpy/linalg/linalg.py:2547, in norm(x, ord, axis, keepdims)
#    2544 elif ord is None or ord == 2:
#    2545     # special case for speedup
#    2546     s = (x.conj() * x).real
# -> 2547     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2548 # None of the str-type keywords for ord ('fro', 'nuc')
#    2549 # are valid for vectors
#    2550 elif isinstance(ord, str):
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
# Wf = model.W
Y = model.S
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Input In [8], in <module>
#       1 # Wf = model.W
#       2 Y = model.S
# ----> 3 Y_ = signed_and_permutation_corrected_sources(S,Y)
#       4 coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
#       5 Y_ = coef_ * Y_
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/src/bss_utils.py:28, in signed_and_permutation_corrected_sources(S, Y)
#      27 def signed_and_permutation_corrected_sources(S,Y):
# ---> 28     perm = find_permutation_between_source_and_estimation(S,Y)
#      29     return (np.sign((Y[perm,:] * S).sum(axis = 1))[:,np.newaxis]) * Y[perm,:]
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/src/bss_utils.py:24, in find_permutation_between_source_and_estimation(S, Y)
#      17 def find_permutation_between_source_and_estimation(S,Y):
#      18     """
#      19     S    : Original source matrix
#      20     Y    : Matrix of estimations of sources (after BSS or ICA algorithm)
#      21
#      22     return the permutation of the source seperation algorithm
#      23     """
# ---> 24     perm = np.argmax(np.abs(outer_prod_broadcasting(Y.T,S.T).sum(axis = 0))/(np.linalg.norm(S,axis = 1)*np.linalg.norm(Y,axis=1)), axis = 0)
#      25     return perm
#
# File <__array_function__ internals>:180, in norm(*args, **kwargs)
#
# File ~/.conda/envs/wsm/lib/python3.8/site-packages/numpy/linalg/linalg.py:2547, in norm(x, ord, axis, keepdims)
#    2544 elif ord is None or ord == 2:
#    2545     # special case for speedup
#    2546     s = (x.conj() * x).real
# -> 2547     return sqrt(add.reduce(s, axis=axis, keepdims=keepdims))
#    2548 # None of the str-type keywords for ord ('fro', 'nuc')
#    2549 # are valid for vectors
#    2550 elif isinstance(ord, str):
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
S.shape

# %%
A.shape

# %%
Agt = np.random.randn(10, 5)
H = np.random.randn(10000, 5)
W = np.random.randn(10, 5)
Y = Agt @ H.T
Lt = 5

# %%
(Lt*np.linalg.norm(np.transpose(W)@W, 2))

# %%
(np.dot(np.transpose(W),(np.dot(W,np.transpose(H)) - Y)))
