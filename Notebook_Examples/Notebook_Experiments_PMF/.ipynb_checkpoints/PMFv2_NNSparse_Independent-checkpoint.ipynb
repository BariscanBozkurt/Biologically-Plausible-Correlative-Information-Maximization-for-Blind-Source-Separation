# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
Sgt = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, size_sources = N, 
                                         decreasing_correlation = True)
Sgt = 4 * Sgt - 2
Sgt = np.clip(ProjectRowstoL1NormBall(Sgt.T).T, 0, 1)
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures,NumberofSources)
Y = np.dot(Agt,Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((Y - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.078 & -0.097 & -0.092 & -0.087 & \\
#  -0.078 & 1.000 & -0.088 & -0.092 & -0.090 & \\
#  -0.097 & -0.088 & 1.000 & -0.091 & -0.087 & \\
#  -0.092 & -0.092 & -0.091 & 1.000 & -0.101 & \\
#  -0.087 & -0.090 & -0.087 & -0.101 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.287 & -0.167 & 0.083 & 2.789 & 0.188 & \\
#  -1.014 & -1.270 & -0.503 & -0.831 & -1.288 & \\
#  -0.714 & 0.269 & 0.163 & 0.070 & -0.555 & \\
#  -0.414 & -0.270 & -0.599 & -1.791 & -1.542 & \\
#  -0.735 & 0.358 & -0.428 & -1.502 & 0.007 & \\
#  1.185 & -0.334 & 0.251 & 0.434 & -0.481 & \\
#  -1.393 & -0.828 & -0.496 & 0.575 & 1.172 & \\
#  -1.027 & 0.633 & 1.114 & -0.354 & 1.221 & \\
#  0.121 & 1.421 & -1.869 & 0.658 & -2.321 & \\
#  0.380 & -1.377 & -0.410 & 0.717 & -0.805 & \\
# \end{bmatrix}$
# Input SNR is : 29.997175661319588

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Y[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 25000
model = PMFv2(s_dim = s_dim, y_dim = y_dim,
              set_ground_truth = True, Sgt = Sgt, Agt = Agt)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_nnsparse(Y, n_iterations = 100000,
                         step_size_scale = 100,
                         debug_iteration_point = debug_iteration_point,
                         plot_in_jupyter = True)
# Out:
# 100%|██████████| 100000/100000 [11:46<00:00, 141.51it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y = model.S
Y_ = signed_and_permutation_corrected_sources(Sgt,Y)
coef_ = ((Y_ * Sgt).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [27.55009605 27.56875229 23.90360946 28.37907293 26.92162021]
#
# Overall SINR : 29.23581151380182

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(Sgt[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
