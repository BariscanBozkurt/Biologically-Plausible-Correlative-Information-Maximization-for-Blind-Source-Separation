# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 8
S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)

print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.011 & -0.001 & -0.023 & 0.002 & \\
#  0.011 & 1.000 & -0.009 & 0.012 & -0.011 & \\
#  -0.001 & -0.009 & 1.000 & -0.017 & -0.002 & \\
#  -0.023 & 0.012 & -0.017 & 1.000 & -0.021 & \\
#  0.002 & -0.011 & -0.002 & -0.021 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.913 & -0.855 & 1.690 & -1.279 & 0.658 & \\
#  -0.082 & 1.392 & -0.256 & 0.664 & -1.440 & \\
#  -0.588 & -0.973 & 0.317 & 0.765 & 0.440 & \\
#  -1.340 & -0.331 & 0.324 & -0.182 & 0.379 & \\
#  -0.440 & -0.081 & 0.471 & 1.023 & -0.391 & \\
#  0.480 & -0.249 & -0.965 & -1.473 & -0.241 & \\
#  0.923 & -0.979 & -1.448 & 0.952 & 1.871 & \\
#  -0.804 & 0.381 & -1.275 & 0.296 & 2.051 & \\
# \end{bmatrix}$
# Input SNR is : 29.998614194552893

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 200
model = PMF(s_dim = s_dim, x_dim = x_dim,
                set_ground_truth = True, Sgt = S, Agt = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_nnantisparse(X, Lt = 50, lambda_ = 10, tau = 1e-8, 
                             plot_in_jupyter = True)
# Out:
# 100%|██████████| 10000/10000 [01:37<00:00, 102.26it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
model.SNR_list
# Out:
# [array([3.48995074e-01, 6.79023905e-01, 1.83377241e-03, 3.48995074e-01,
#         6.38698189e-05]),
#  array([1.56951655, 0.48446942, 7.76243803, 3.8069742 ,        inf]),
#  array([1.41794907, 0.39534247, 7.12349345, 3.98232615,        inf]),
#  array([1.4645965 , 0.43891608, 5.57825931, 4.36474806,        inf]),
#  array([1.44289566, 0.50078011, 4.63248533, 4.70040578,        inf]),
#  array([1.36615763, 0.53327007, 4.22818635, 4.92379022,        inf]),
#  array([1.32542608, 0.55055368, 3.57425348, 5.19182893,        inf]),
#  array([1.27940305, 0.59213991, 3.31344939, 5.60349931,        inf]),
#  array([1.22193448, 0.6114785 , 3.16366077, 5.96722596,        inf]),
#  array([1.21653383, 0.64186603, 3.02621265, 6.3278491 ,        inf]),
#  array([1.21862747, 0.67143505, 2.85614776, 6.78329488,        inf]),
#  array([1.22319016, 0.68485746, 2.7661704 , 7.17929792,        inf]),
#  array([1.22173302, 0.69741716, 2.67068941, 7.74537551,        inf]),
#  array([1.20574965, 0.71231372, 2.54783306, 8.47924611,        inf]),
#  array([1.16699746, 0.75276191, 2.36218648, 9.34635495,        inf]),
#  array([1.13696663, 0.76170913, 2.20069824, 9.81353501, 9.81353501]),
#  array([1.12505208, 0.75062317, 1.66563488, 9.88794276, 9.88794276]),
#  array([1.12454539, 0.7471834 , 1.68499045,        inf, 9.96627322]),
#  array([1.15393233, 0.73697762, 1.68909197,        inf, 9.97911823]),
#  array([1.1637467 , 0.7228568 , 1.70110547,        inf, 9.93526187]),
#  array([1.1606574 , 0.72150985, 1.71676604,        inf, 9.88055377]),
#  array([1.17487367, 0.70543488, 1.71869492,        inf, 9.91193229]),
#  array([1.1938158 , 0.69960978, 1.72372009,        inf, 9.90479126]),
#  array([1.20793683, 0.6960234 , 1.71806074,        inf, 9.9048751 ]),
#  array([1.21283243, 0.69355794, 1.71395773,        inf, 9.89151418]),
#  array([1.21574538, 0.7726245 , 1.71929555,        inf, 9.91014384]),
#  array([1.21883563, 0.77000767, 1.72069658,        inf, 9.90683801]),
#  array([1.22050965, 0.76757179, 1.72176984,        inf, 9.90997646]),
#  array([1.2198331 , 0.76713902, 1.72230111,        inf, 9.90280785]),
#  array([1.22057124, 0.7674386 , 1.72217069,        inf, 9.90469159]),
#  array([1.22119631, 0.76771869, 1.72192866,        inf, 9.90700112]),
#  array([1.22194511, 0.76801003, 1.72205839,        inf, 9.90871713]),
#  array([1.22230366, 0.76853727, 1.72209524,        inf, 9.90932093]),
#  array([1.22208525, 0.76901174, 1.72238512,        inf, 9.90550745]),
#  array([1.22203304, 0.76930807, 1.72334365,        inf, 9.90404826]),
#  array([1.22158381, 0.76969156, 1.72480903,        inf, 9.89984948]),
#  array([1.22127184, 0.77049412, 1.72565176,        inf, 9.89657379]),
#  array([1.22022831, 0.77135247, 1.72596259,        inf, 9.89301291]),
#  array([1.21939439, 0.77229048, 1.72588318,        inf, 9.88813006]),
#  array([1.21933315, 0.77249908, 1.72572352,        inf, 9.88720026]),
#  array([1.2192263 , 0.77249908, 1.72572352,        inf, 9.88362441]),
#  array([1.21912339, 0.77249934, 1.72572352,        inf, 9.88212944]),
#  array([1.21782492, 0.77266458, 1.72572352,        inf, 9.87139739]),
#  array([1.21731842, 0.77323882, 1.72572352,        inf, 9.8658516 ]),
#  array([1.21760425, 0.77385025, 1.72572227,        inf, 9.86582737]),
#  array([1.21731542, 0.77410104, 1.72565509,        inf, 9.86525495]),
#  array([1.21622637, 0.774101  , 1.72507696,        inf, 9.86052245]),
#  array([1.21494597, 0.77409375, 1.72537117,        inf, 9.85398278]),
#  array([1.21423928, 0.77401302, 1.72600483,        inf, 9.85233869]),
#  array([1.21376132, 0.77401133, 1.72601181,        inf, 9.84970324]),
#  array([1.21354797, 0.77401133, 1.72601181,        inf, 9.84817466]),
#  array([1.21343434, 0.77401133, 1.72601181,        inf, 9.84795083]),
#  array([1.21314763, 0.77401133, 1.72601181,        inf, 9.84666542]),
#  array([1.21271233, 0.77401793, 1.72601923,        inf, 9.84377672]),
#  array([1.21251019, 0.77410713, 1.72611846,        inf, 9.84390088]),
#  array([1.21195823, 0.77439141, 1.72642192,        inf, 9.84210329]),
#  array([1.21191163, 0.77497578, 1.72697224,        inf, 9.84386653]),
#  array([1.21178447, 0.77497578, 1.72697224,        inf, 9.84360642]),
#  array([1.21148848, 0.77497578, 1.72697224,        inf, 9.84221811]),
#  array([1.21111797, 0.77497578, 1.72697224,        inf, 9.83946094]),
#  array([1.21105989, 0.77497578, 1.72697224,        inf, 9.83941235]),
#  array([1.2109048 , 0.77497578, 1.72697224,        inf, 9.83907608]),
#  array([1.21061189, 0.77497578, 1.72697224,        inf, 9.83749914]),
#  array([1.21008118, 0.77497578, 1.72697224,        inf, 9.83203046]),
#  array([1.21018597, 0.77497578, 1.72697224,        inf, 9.82782755]),
#  array([1.21030373, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21030074, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.2102952 , 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.210286  , 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21027186, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21025137, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21022315, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21018615, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21013996, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21008512, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.21002327, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20995719, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20989056, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20982761, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20977259, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20972922, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20971337, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20972669, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.2097515 , 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20978443, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20982183, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20986007, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.209896  , 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20992703, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20995125, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20996736, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20997453, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20997229, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20996045, 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.2099391 , 0.77497578, 1.72697224,        inf, 9.82654261]),
#  array([1.20990864, 0.77497578, 1.72697227,        inf, 9.82654278]),
#  array([1.20986994, 0.77497577, 1.72697803,        inf, 9.82658402]),
#  array([1.20982457, 0.77497569, 1.72700756,        inf, 9.82679352]),
#  array([1.20977519, 0.77497504, 1.72707795,        inf, 9.82728066]),
#  array([1.20972584, 0.77497216, 1.72720112,        inf, 9.82808796]),
#  array([1.20971375, 0.77496357, 1.7273786 ,        inf, 9.82913545])]

# %%
# Wf = model.W
Y = model.S_
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [5.01322589 5.21253175 5.14150364 6.52669339 6.4332075 ]
#
# Overall SINR : 12.861870566963374

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
S.shape
# Out:
# (5, 10000)

# %%
A.shape
# Out:
# (8, 5)

# %%
Agt = np.random.randn(10, 5)
H = np.random.randn(10000, 5)
W = np.random.randn(10, 5)
Y = Agt @ H.T
Lt = 5

# %%
(Lt*np.linalg.norm(np.transpose(W)@W, 2))
# Out:
# 158.39859703063294

# %%
(np.dot(np.transpose(W),(np.dot(W,np.transpose(H)) - Y)))
# Out:
# array([[-21.8040605 ,   4.92458255,   2.73524882, ...,  18.91953682,
#          -8.96699462, -14.60564648],
#        [-16.8406084 ,   5.94676762,   1.37063509, ...,  29.3917296 ,
#         -23.44669851, -13.13595465],
#        [ 12.27218131,   2.06269643,  -2.69451623, ..., -16.48301864,
#           4.71195921,   5.56492864],
#        [  9.21217093,  -7.4540606 ,   1.08112071, ...,  27.73400812,
#         -35.55089049,   6.46130769],
#        [ 71.39541518, -11.47074596, -13.38354881, ..., -44.21718794,
#          10.48128013,  41.87602751]])
