# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from PMF import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 10
Sgt = generate_correlated_copula_sources(
    rho=0.7,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)

Sgt = 2 * Sgt - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(Sgt))

# Generate Mxr random mixing from i.i.d N(0,1)
Agt = np.random.randn(NumberofMixtures, NumberofSources)
Y = np.dot(Agt, Sgt)

SNR = 30
Y, NoisePart = addWGN(Y, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((Y - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(Agt)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.674 & 0.459 & 0.332 & 0.238 & \\
#  0.674 & 1.000 & 0.672 & 0.475 & 0.345 & \\
#  0.459 & 0.672 & 1.000 & 0.675 & 0.460 & \\
#  0.332 & 0.475 & 0.675 & 1.000 & 0.669 & \\
#  0.238 & 0.345 & 0.460 & 0.669 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.207 & -0.679 & -2.414 & 1.141 & 1.056 & \\
#  -0.643 & -0.146 & 0.369 & -1.570 & 0.427 & \\
#  -2.064 & -2.036 & 0.829 & 0.134 & -0.947 & \\
#  1.441 & -0.613 & 1.581 & -0.070 & -1.432 & \\
#  -0.018 & 0.536 & -0.061 & 0.645 & -0.845 & \\
#  -0.449 & 1.782 & -1.381 & 0.327 & 0.511 & \\
#  -0.006 & 1.305 & 0.331 & 0.188 & 0.081 & \\
#  -0.771 & 0.814 & 0.353 & -0.308 & -0.253 & \\
#  -1.165 & 0.011 & -0.604 & -1.307 & -0.052 & \\
#  -0.798 & -0.186 & 2.035 & 0.416 & -0.210 & \\
# \end{bmatrix}$
# Input SNR is : 29.992628750715966

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    Y[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = Sgt.shape[0]
y_dim = Y.shape[0]
debug_iteration_point = 5000
model = PMF(s_dim=s_dim, y_dim=y_dim, set_ground_truth=True, Sgt=Sgt, Agt=Agt)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_antisparse(
    Y,
    n_iterations=15000,
    Lt=50,
    lambda_=28,
    tau=1e-10,
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 15000/15000 [00:30<00:00, 489.15it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Y = model.S
Y_ = signed_and_permutation_corrected_sources(Sgt, Y)
coef_ = ((Y_ * Sgt).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(Sgt, Y_)))

SINR = 10 * np.log10(CalculateSINRjit(Y_, Sgt)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [26.2722599  25.12082096 25.04542284 22.16731937 22.21284029]
#
# Overall SINR : 23.819763570612306

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    Sgt[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
