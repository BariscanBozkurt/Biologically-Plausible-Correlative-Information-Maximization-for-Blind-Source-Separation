# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from LDMIBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10

S = generate_uniform_points_in_simplex(NumberofSources, N)

print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))
plt.scatter(S[0,:], S[1,:])

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.251 & -0.250 & -0.250 & -0.250 & \\
#  -0.251 & 1.000 & -0.250 & -0.248 & -0.250 & \\
#  -0.250 & -0.250 & 1.000 & -0.249 & -0.252 & \\
#  -0.250 & -0.248 & -0.249 & 1.000 & -0.250 & \\
#  -0.250 & -0.250 & -0.252 & -0.250 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -0.035 & 0.671 & -1.816 & -0.140 & 0.818 & \\
#  -0.219 & 0.052 & -0.400 & 0.483 & 0.939 & \\
#  0.149 & -0.022 & 0.538 & 1.348 & -0.777 & \\
#  -0.121 & 1.056 & -0.531 & 0.338 & -0.124 & \\
#  0.623 & 0.794 & -1.448 & 0.479 & 0.223 & \\
#  -0.097 & 0.357 & 1.807 & 1.166 & -0.815 & \\
#  0.477 & -0.101 & -0.405 & -2.902 & -0.978 & \\
#  -0.089 & -0.360 & -1.180 & 0.111 & -0.377 & \\
#  0.684 & -1.299 & -0.867 & -0.174 & 0.572 & \\
#  -2.125 & -1.428 & -0.003 & 0.362 & -0.573 & \\
# \end{bmatrix}$
# Input SNR is : 30.002206714772427

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 600
model = MinibatchLDMIBSS(s_dim = s_dim, x_dim = x_dim,
                         set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_simplex(X, batch_size = 20000, epsilon = 1e-5, mu_start = 200, 
                            n_iterations_per_batch = 600, method = "covariance", 
                            debug_iteration_point = debug_iteration_point,
                            plot_in_jupyter = True)
print('Algorithm took %f sec.' % (t.interval))
# Out:
# 100%|██████████| 600/600 [00:12<00:00, 46.26it/s]
# Algorithm took 686.232700 sec.

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.W
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S, False)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [29.20267913 32.66318811 32.82469008 32.25144798 30.66378487]
#
# Overall SINR : 31.707126671422678

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
