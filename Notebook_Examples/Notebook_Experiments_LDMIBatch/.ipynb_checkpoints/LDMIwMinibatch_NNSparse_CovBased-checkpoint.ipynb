# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from LDMIBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10

S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = True)
S = 2 * S - 1
S = ProjectRowstoL1NormBall(S.T).T
S = S * (S >= 0)

print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

plt.scatter(S[0,:], S[2,:])

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.074 & -0.075 & -0.077 & -0.078 & \\
#  -0.074 & 1.000 & -0.077 & -0.077 & -0.076 & \\
#  -0.075 & -0.077 & 1.000 & -0.076 & -0.078 & \\
#  -0.077 & -0.077 & -0.076 & 1.000 & -0.076 & \\
#  -0.078 & -0.076 & -0.078 & -0.076 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -2.167 & 0.117 & -1.390 & -1.389 & -0.864 & \\
#  -0.178 & -0.367 & -0.049 & 1.006 & 0.650 & \\
#  -1.233 & -1.022 & 1.860 & -0.354 & 0.401 & \\
#  0.232 & -0.256 & 1.220 & 1.496 & -0.198 & \\
#  -1.853 & -1.019 & 0.353 & -1.100 & 0.350 & \\
#  -0.693 & 0.028 & -1.267 & 2.492 & -0.886 & \\
#  0.093 & -0.297 & 0.335 & -1.227 & -0.978 & \\
#  -0.480 & 0.889 & 0.723 & -0.013 & -0.887 & \\
#  -1.065 & 1.984 & -1.478 & 0.490 & 1.116 & \\
#  1.815 & -0.055 & -0.116 & 1.332 & 0.478 & \\
# \end{bmatrix}$
# Input SNR is : 30.001753817925852

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 600
model = MinibatchLDMIBSS(s_dim = s_dim, x_dim = x_dim,
                         set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_nnsparse(X, batch_size = 20000, epsilon = 1e-5, mu_start = 200, 
                             n_iterations_per_batch = 600, method = "covariance", 
                             debug_iteration_point = debug_iteration_point,
                             plot_in_jupyter = True)
print('Algorithm took %f sec.' % (t.interval))
# Out:
#  16%|█▌        | 95/600 [00:09<00:21, 23.15it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.W
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
