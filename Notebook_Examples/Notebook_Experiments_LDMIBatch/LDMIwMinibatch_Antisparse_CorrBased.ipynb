# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from LDMIBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.5, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)

S = 2 * S - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.469 & 0.468 & 0.468 & 0.469 & \\
#  0.469 & 1.000 & 0.469 & 0.469 & 0.469 & \\
#  0.468 & 0.469 & 1.000 & 0.468 & 0.469 & \\
#  0.468 & 0.469 & 0.468 & 1.000 & 0.468 & \\
#  0.469 & 0.469 & 0.469 & 0.468 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.585 & -1.601 & 0.012 & -0.941 & 0.049 & \\
#  -0.583 & -2.127 & 0.191 & -0.246 & 1.342 & \\
#  -0.165 & 0.226 & 0.436 & 0.276 & 1.453 & \\
#  -0.357 & 0.310 & -2.015 & 0.316 & -0.140 & \\
#  -0.892 & 0.617 & -0.415 & 1.399 & -0.795 & \\
#  -0.127 & -0.662 & 0.501 & 0.949 & -1.148 & \\
#  1.001 & -0.236 & -1.462 & -0.943 & -0.206 & \\
#  1.454 & 0.088 & 0.196 & 0.711 & 0.507 & \\
#  -0.484 & -0.052 & 2.101 & -0.226 & 0.958 & \\
#  1.288 & 0.142 & 0.054 & -0.295 & 0.001 & \\
# \end{bmatrix}$
# Input SNR is : 29.99849746048738

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 1000
model = MinibatchLDMIBSS(s_dim = s_dim, x_dim = x_dim,
                     set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_antisparse(X, batch_size = 20000, epsilon = 1e-5, mu_start = 100, 
                               n_iterations_per_batch = 1000, method = "correlation", 
                               debug_iteration_point = debug_iteration_point,
                               plot_in_jupyter = True)
    
print('Algorithm took %f sec.' % (t.interval))
# Out:
# 100%|██████████| 1000/1000 [00:33<00:00, 29.69it/s]
# Algorithm took 869.792527 sec.

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.W
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [30.67979956 31.22588321 31.93597447 28.73612392 30.03240979]
#
# Overall SINR : 30.377055004786598

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
