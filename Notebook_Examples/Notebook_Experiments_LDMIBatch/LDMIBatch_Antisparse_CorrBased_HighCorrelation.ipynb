# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from LDMIBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 10000
NumberofSources = 5
NumberofMixtures = 8
S = generate_correlated_copula_sources(rho = 0.6, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)
S = 2 * S -1 
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.573 & 0.574 & 0.568 & 0.568 & \\
#  0.573 & 1.000 & 0.573 & 0.571 & 0.575 & \\
#  0.574 & 0.573 & 1.000 & 0.572 & 0.578 & \\
#  0.568 & 0.571 & 0.572 & 1.000 & 0.573 & \\
#  0.568 & 0.575 & 0.578 & 0.573 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -2.308 & 0.856 & 2.661 & 2.126 & 0.567 & \\
#  -0.371 & -0.535 & 0.690 & -0.122 & -0.643 & \\
#  0.295 & 0.323 & -0.317 & -0.283 & -0.593 & \\
#  1.338 & 0.612 & -0.324 & -1.715 & 0.750 & \\
#  -0.676 & -1.239 & 1.197 & -0.593 & -0.247 & \\
#  -0.256 & -2.058 & -0.906 & -0.247 & -0.064 & \\
#  -0.186 & -1.641 & 1.664 & 1.347 & 1.175 & \\
#  0.205 & 0.554 & -0.899 & -0.432 & -1.174 & \\
# \end{bmatrix}$
# Input SNR is : 30.004907617852933

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 200
model = LDMIBSS(s_dim = s_dim, x_dim = x_dim,
                set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_antisparse(X, epsilon = 1e-5, mu_start = 100, n_iterations = 10000, 
                           method = "correlation", debug_iteration_point = debug_iteration_point,
                           plot_in_jupyter = True)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.W
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# Component SNR Values : [22.91274818 25.99067176 25.23014158 25.6377689  27.69051987]
#
# Overall SINR : 25.19699644930185

# %%
CalculateSIR(A, Wf)
# Out:
# (31.770540767631502, 5)

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
