# %% [markdown]
# # Import Required Libraries

# %%
import sys

sys.path.insert(0, "../../src")
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from LDMIBSS import *
from general_utils import *
from polytope_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "General_Polytope_5dim"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
dim = 5
N = 10000
NumberofSources = dim
NumberofMixtures = 10

signed_dims = np.array([0, 1, 3])
nn_dims = np.array([2, 4])
sparse_dims_list = [np.array([0, 1, 4]), np.array([1, 2, 3])]
(A, b), V = generate_practical_polytope(dim, signed_dims, nn_dims, sparse_dims_list)
S = generate_uniform_points_in_polytope(V, N)

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
plt.scatter(S[0, :], S[1, :])
plt.xlabel("$S_{:,1}$", fontsize=25)
plt.ylabel("$S_{:,2}$", fontsize=25)
plt.grid(linewidth=0.2)
plt.subplot(1, 3, 2)
plt.scatter(S[0, :], S[2, :])
plt.xlabel("$S_{:,1}$", fontsize=25)
plt.ylabel("$S_{:,3}$", fontsize=25)
plt.grid(linewidth=0.2)
plt.subplot(1, 3, 3)
plt.scatter(S[1, :], S[2, :])
plt.xlabel("$S_{:,2}$", fontsize=25)
plt.ylabel("$S_{:,3}$", fontsize=25)
plt.grid(linewidth=0.2)

plt.suptitle("Scatter Plot of Source Components", fontsize=30)
# plt.savefig('Pex_source_components.pdf', format='pdf', dpi = 1200)
# Out:
# Text(0.5, 0.98, 'Scatter Plot of Source Components')

# %%
# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.374 & -0.154 & 0.459 & -0.425 & 2.078 & \\
#  -0.629 & -1.240 & -0.730 & 0.818 & 0.229 & \\
#  0.403 & -0.704 & 0.483 & 1.315 & 0.769 & \\
#  -0.730 & 0.945 & -0.349 & -0.013 & 1.027 & \\
#  0.013 & -1.269 & -0.046 & -0.013 & -2.453 & \\
#  -0.051 & 0.343 & 0.760 & -1.238 & -2.342 & \\
#  0.039 & 0.005 & -1.968 & -0.029 & -1.257 & \\
#  -0.238 & 1.407 & 0.674 & -0.313 & -0.323 & \\
#  -0.003 & -0.734 & 0.311 & -1.714 & -0.717 & \\
#  2.093 & 1.002 & -2.171 & -1.044 & -0.133 & \\
# \end{bmatrix}$
# Input SNR is : 29.975554878099974

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 1000
model = LDMIBSS(s_dim=s_dim, x_dim=x_dim, set_ground_truth=True, S=S, A=A)

# %% [markdown]
# # Run LDMI Algorithm on Mixture Signals

# %%
model.fit_batch_general_polytope(
    X,
    signed_dims,
    nn_dims,
    sparse_dims_list,
    epsilon=1e-5,
    mu_start=200,
    n_iterations=10000,
    method="correlation",
    lr_rule="inv_sqrt",
    debug_iteration_point=debug_iteration_point,
    plot_in_jupyter=True,
)
# Out:
# 100%|██████████| 10000/10000 [02:26<00:00, 68.10it/s]

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.W
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10 * np.log10(CalculateSINRjit(Y_, S, False)[0])

print("Overall SINR : {}".format(SINRwsm))
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.
# Component SNR Values : [29.53243863 29.61265368 31.92709589 31.35850864 33.994373  ]
#
# Overall SINR : 31.28559236731131

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
