# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from BCA import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.2, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = True)

S = 2 * S - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.186 & 0.038 & 0.008 & 0.002 & \\
#  0.186 & 1.000 & 0.183 & 0.036 & 0.008 & \\
#  0.038 & 0.183 & 1.000 & 0.183 & 0.035 & \\
#  0.008 & 0.036 & 0.183 & 1.000 & 0.186 & \\
#  0.002 & 0.008 & 0.035 & 0.186 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.827 & 1.759 & 0.919 & -1.126 & -0.552 & \\
#  -0.176 & 0.266 & 0.007 & 0.525 & 0.798 & \\
#  1.939 & 0.380 & 0.540 & -1.169 & -2.981 & \\
#  1.599 & -0.777 & -0.679 & -2.221 & -0.128 & \\
#  -0.642 & -0.585 & -0.874 & -0.298 & -1.011 & \\
#  -0.436 & 0.611 & -0.255 & 1.372 & -0.011 & \\
#  0.618 & 1.041 & -0.342 & -0.345 & -0.507 & \\
#  -0.792 & -1.658 & -0.478 & 0.563 & -0.038 & \\
#  -0.549 & 1.511 & 1.334 & -0.332 & -0.738 & \\
#  -0.879 & -0.950 & -0.533 & -1.245 & 1.318 & \\
# \end{bmatrix}$
# Input SNR is : 30.001103723104336

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
# HYPERPARAMETERS DEFINED IN THE PAPER
lambda_ = 0.99
mu_F = 1e-3
beta = 30
debug_iteration_point = 25000

model = OnlineBCA(s_dim = NumberofSources, x_dim = NumberofMixtures, 
                  lambda_ = lambda_, mu_F = mu_F, beta = beta, 
                  set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_antisparse(X, n_epochs = 1, 
                               neural_lr_start = 0.9,
                               neural_dynamic_iterations = 500, 
                               shuffle = False, 
                               debug_iteration_point = debug_iteration_point,
                               plot_in_jupyter = True)
print('Algorithm took %f sec.' % (t.interval))
# Out:
# 100%|██████████| 500000/500000 [01:35<00:00, 5220.85it/s]
# Algorithm took 95.918999 sec.

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(model.SIR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

print('Final SINR: {}'.format(np.array(model.SIR_list[-1])))
# Out:
# Final SINR: 25.53065917756178

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [25.33790212 26.47553156 24.88196807 26.98647046 25.19736892]
#
# Overall SINR : 25.69157983776997

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_[:,0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
