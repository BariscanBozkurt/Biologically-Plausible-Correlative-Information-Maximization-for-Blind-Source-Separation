# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os

os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from BCA import *
from general_utils import *
from visualization_utils import *

import warnings

warnings.filterwarnings("ignore")

notebook_name = "Nonnegative_Antisparse_Copula"

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(
    rho=0.7,
    df=4,
    n_sources=NumberofSources,
    size_sources=N,
    decreasing_correlation=True,
)

S = 2 * S - 1
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures, NumberofSources)
X = np.dot(A, S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.669 & 0.460 & 0.319 & 0.223 & \\
#  0.669 & 1.000 & 0.667 & 0.459 & 0.319 & \\
#  0.460 & 0.667 & 1.000 & 0.670 & 0.461 & \\
#  0.319 & 0.459 & 0.670 & 1.000 & 0.668 & \\
#  0.223 & 0.319 & 0.461 & 0.668 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  -1.138 & -0.883 & -0.203 & 0.551 & 0.389 & \\
#  0.614 & -0.734 & 0.301 & 1.111 & 1.218 & \\
#  0.970 & 0.957 & 0.900 & -1.066 & -0.730 & \\
#  -0.173 & -0.427 & -0.769 & 0.962 & 1.047 & \\
#  2.793 & -1.352 & -0.279 & -1.005 & -1.467 & \\
#  1.323 & 0.577 & 0.033 & 0.977 & 0.028 & \\
#  -1.401 & -0.141 & 1.025 & -0.278 & 0.709 & \\
#  2.140 & -0.636 & -1.009 & -0.988 & -0.229 & \\
#  0.490 & -2.009 & 0.815 & 0.174 & -2.073 & \\
#  0.710 & -1.007 & 0.266 & -1.462 & -0.297 & \\
# \end{bmatrix}$
# Input SNR is : 30.001576272161653

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
subplot_1D_signals(
    X[:, 0:100], title="Mixture Signals", figsize=(15, 18), colorcode=None
)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
# HYPERPARAMETERS DEFINED IN THE PAPER
lambda_ = 0.99
mu_F = 1e-3
beta = 30
debug_iteration_point = 25000

model = OnlineBCA(
    s_dim=NumberofSources,
    x_dim=NumberofMixtures,
    lambda_=lambda_,
    mu_F=mu_F,
    beta=beta,
    set_ground_truth=True,
    S=S,
    A=A,
)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
with Timer() as t:
    model.fit_batch_antisparse(
        X,
        n_epochs=1,
        neural_lr_start=0.9,
        neural_dynamic_iterations=500,
        shuffle=False,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
print("Algorithm took %f sec." % (t.interval))
# Out:
# 100%|██████████| 500000/500000 [02:14<00:00, 3710.89it/s]
# Algorithm took 135.006804 sec.

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams["xtick.labelsize"] = 18
mpl.rcParams["ytick.labelsize"] = 18
plot_convergence_plot(
    model.SIR_list,
    xlabel="Number of Iterations / {}".format(debug_iteration_point),
    ylabel="SINR (dB)",
    title="SINR Convergence Plot",
    colorcode=None,
    linewidth=1.8,
)

print("Final SINR: {}".format(np.array(model.SIR_list[-1])))
# Out:
# Final SINR: 20.422870768598518

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping=True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S, Y)
coef_ = ((Y_ * S).sum(axis=1) / (Y_ * Y_).sum(axis=1)).reshape(-1, 1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10 * np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [19.71370257 21.48935043 23.15409753 22.59045681 23.41928956]
#
# Overall SINR : 21.822745282931244

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(
    Y_[:, 0:100],
    title="Extracted Signals (Sign and Permutation Corrected)",
    figsize=(15.2, 9),
    colorcode=None,
)
subplot_1D_signals(
    S[:, 0:100], title="Original Signals", figsize=(15.2, 9), colorcode=None
)
