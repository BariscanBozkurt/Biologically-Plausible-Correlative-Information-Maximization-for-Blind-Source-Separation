# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from WSMBSS import *
from numba import njit
from IPython import display
import pylab as pl
import warnings
warnings.filterwarnings("ignore")
# np.random.seed(874)
# %load_ext autoreload
# %autoreload 2
notebook_name = 'Nonnegative_Antisparse_Copula'

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
rho = 0.0
N = 500000
NumberofSources = 5
NumberofMixtures = 10

M = NumberofMixtures
r = NumberofSources
INPUT_STD = 0.28
SNR = 30 # dB

S = generate_correlated_copula_sources(rho = rho, df = 4, n_sources = NumberofSources, size_sources = N , 
                                       decreasing_correlation = False)

A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
X = A @ S

# A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
# X = A @ S
# for MM in range(A.shape[0]):
#     stdx = np.std(X[MM,:])
#     A[MM,:] = A[MM,:]/stdx * INPUT_STD
# X = A @ S

X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))

print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.102 & -0.201 & 1.406 & -0.208 & 0.443 & \\
#  -1.684 & -1.265 & 0.177 & -2.207 & -0.285 & \\
#  -1.744 & 0.720 & 0.597 & -0.387 & 0.785 & \\
#  -1.383 & -0.481 & 0.286 & 2.430 & -1.554 & \\
#  -0.879 & 0.152 & 0.197 & 0.382 & -1.044 & \\
#  1.001 & 0.173 & 0.806 & -1.340 & 0.872 & \\
#  -0.630 & 0.334 & 0.149 & 1.437 & -2.010 & \\
#  0.968 & -0.346 & -0.508 & 0.669 & 1.671 & \\
#  -1.679 & -0.845 & 0.507 & 0.282 & 0.518 & \\
#  -0.504 & -1.483 & 0.862 & -2.024 & 0.325 & \\
# \end{bmatrix}$
# Input SNR is : 30.000803330165382

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S[:,0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X[:,0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
gamma_start = 0.1
gamma_stop = 1e-3
OUTPUT_COMP_TOL = 1e-6
MAX_OUT_ITERATIONS= 3000
LayerGains = [1,1]
LayerMinimumGains = [1,1]
LayerMaximumGains = [1e6,5]
WScalings = [0.005,0.005]
GamScalings = [1,1]
zeta = 1*1e-4
beta = 0.5
muD = [.1, 1e-3]

s_dim = S.shape[0]
x_dim = X.shape[0]
h_dim = x_dim
samples = S.shape[1]
W_HX = np.eye(h_dim, x_dim)
W_YH = np.eye(s_dim, h_dim)

# %%
np.linalg.svd(A)
# Out:
# (array([[-0.16979984,  0.14457909,  0.14285484,  0.65476496, -0.4062512 ,
#          -0.46006884, -0.00965062,  0.0168615 , -0.00746153, -0.35214167],
#         [-0.26753008, -0.62642256,  0.14661661, -0.12095879,  0.27312573,
#          -0.00109783,  0.11083157,  0.12198038, -0.19416247, -0.60036171],
#         [-0.04770221, -0.29005666, -0.49680343, -0.27747648, -0.6458012 ,
#          -0.13400669,  0.09659565,  0.10104999, -0.34891071,  0.11613485],
#         [ 0.58429269, -0.20905833, -0.12408856,  0.43877412,  0.08125025,
#           0.2809854 , -0.28479878, -0.12935565, -0.47004585, -0.05133451],
#         [ 0.21148171, -0.19827452,  0.13258106, -0.04927556, -0.15635108,
#          -0.01499687, -0.51040507,  0.69906428,  0.34889532,  0.01881953],
#         [-0.35951085,  0.11271984,  0.14385578,  0.14608204, -0.36358108,
#           0.81648519,  0.02925375,  0.08609997, -0.00453094, -0.09424947],
#         [ 0.46894282, -0.10697554,  0.32836942,  0.05794466, -0.14571393,
#           0.0436423 ,  0.74983154,  0.24957161,  0.06794391,  0.07195768],
#         [-0.1184556 ,  0.33985229, -0.51071098,  0.20063917,  0.36469947,
#           0.03709097,  0.22877287,  0.58564226, -0.18200261, -0.08103481],
#         [ 0.03612633, -0.35306506, -0.51426762,  0.28803063,  0.02055276,
#           0.12762191,  0.1421874 , -0.21231811,  0.66459091, -0.05403743],
#         [-0.38302147, -0.39400075,  0.15648917,  0.36985476,  0.15938625,
#          -0.07059859,  0.03180302,  0.10698878, -0.1356193 ,  0.68959248]]),
#  array([5.10382338, 4.26192406, 2.39233168, 1.97797369, 1.81967454]),
#  array([[-0.2518054 ,  0.14938767, -0.11310386,  0.78511453, -0.53392888],
#         [ 0.81757572,  0.32238237, -0.18668201,  0.35224659,  0.26212919],
#         [ 0.44286847,  0.00924159,  0.09165881, -0.39147204, -0.8013304 ],
#         [ 0.24229866, -0.61351586,  0.67686868,  0.32341697,  0.04625914],
#         [ 0.11542468, -0.70517077, -0.69699699,  0.04084863, -0.04402173]]))

# %% [markdown]
# # Run WSM Algorithm on Mixture Signals

# %%
debug_iteration_point = 25000
modelWSM = OnlineWSMBSS( s_dim = s_dim, x_dim = x_dim, h_dim = h_dim, 
                         gamma_start = gamma_start, gamma_stop = gamma_stop, beta = beta, zeta = zeta, 
                         muD = muD,WScalings = WScalings, GamScalings = GamScalings,
                         W_HX = W_HX, W_YH = W_YH,
                         DScalings = LayerGains, LayerMinimumGains = LayerMinimumGains,
                         LayerMaximumGains = LayerMaximumGains,neural_OUTPUT_COMP_TOL = OUTPUT_COMP_TOL,
                         set_ground_truth = True, S = S, A = A)


modelWSM.fit_batch_nnantisparse( X, n_epochs = 1, 
                                 neural_dynamic_iterations = 750,
                                 neural_lr_start = 0.7,
                                 neural_lr_stop = 0.01,
#                                  synaptic_lr_rule = synaptic_lr_rule,
#                                  neural_loop_lr_rule = neural_loop_lr_rule,
                                 debug_iteration_point = debug_iteration_point,
                                 hidden_layer_gain = 25, plot_in_jupyter = True,
                                )
# Out:
#  13%|█▎        | 66470/500000 [05:49<27:23, 263.84it/s]

# %% [markdown]
# # Visualize SNR Convergence of Each Source Component

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(modelWSM.SNR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = modelWSM.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINRwsm = 10*np.log10(CalculateSINRjit(Y_, S)[0])

print("Overall SINR : {}".format(SINRwsm))

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
subplot_1D_signals(Y_.T[0:100], title = 'Extracted Signals (Sign and Permutation Corrected)', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
