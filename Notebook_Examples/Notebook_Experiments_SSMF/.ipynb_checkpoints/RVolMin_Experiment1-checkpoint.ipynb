# %%
import sys
import os
os.chdir("..")
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import pylab as pl

from SSMF import *
from PMF import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse'

# %%
N = 10000
NumberofSources = 10
NumberofMixtures = 50
S = np.random.exponential(scale=1.0, size=(NumberofSources,int(N)))
S = S / np.sum(S, axis = 0)
# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.874 & -0.787 & 1.300 & -0.244 & -0.786 & 0.996 & -0.913 & 0.638 & 0.979 & 0.416 & \\
#  0.492 & 0.711 & -0.432 & 0.307 & -0.330 & 0.738 & -0.180 & 0.571 & -0.086 & 0.492 & \\
#  1.779 & 0.760 & 0.231 & -0.320 & -1.211 & 0.182 & 0.458 & 1.462 & -0.930 & 1.596 & \\
#  0.798 & -1.542 & -1.360 & 0.338 & 2.050 & -0.240 & 0.841 & -0.207 & -2.047 & 1.128 & \\
#  0.097 & -1.238 & -2.257 & -1.154 & -1.356 & 1.267 & 1.241 & -0.941 & -0.215 & 1.020 & \\
#  1.141 & 0.858 & -0.416 & -1.102 & -1.167 & -0.371 & -1.877 & 1.120 & 1.508 & -0.349 & \\
#  0.004 & 0.694 & -0.201 & 0.276 & 0.640 & -0.208 & -0.890 & 1.469 & -0.405 & 0.591 & \\
#  0.955 & -0.304 & 0.348 & 0.422 & 0.729 & -0.735 & -0.074 & 0.529 & 0.705 & -0.869 & \\
#  0.740 & -0.296 & 0.200 & -0.552 & -0.448 & 0.727 & 0.123 & -1.200 & -0.043 & -0.796 & \\
#  -2.479 & 0.989 & 0.317 & 0.414 & 1.074 & 0.595 & -1.118 & 0.568 & 0.579 & -0.567 & \\
#  -0.408 & 0.596 & 0.375 & 0.370 & 0.045 & 0.229 & -0.130 & -0.620 & 0.527 & 0.789 & \\
#  1.218 & 1.160 & -0.414 & -0.443 & 0.325 & 0.364 & 0.984 & -1.275 & -0.538 & -0.161 & \\
#  -0.507 & -0.487 & -1.158 & -0.569 & 0.124 & -0.214 & 2.566 & -0.395 & 0.612 & 0.175 & \\
#  -1.375 & -0.669 & 0.954 & 0.222 & 0.874 & 1.146 & -0.467 & 1.947 & -1.151 & 1.404 & \\
#  -0.192 & -0.192 & 0.065 & 0.091 & 0.895 & 0.555 & -0.648 & -1.532 & 1.595 & -0.364 & \\
#  0.114 & 0.708 & -0.506 & -0.173 & 0.025 & 0.275 & 0.448 & -2.602 & 0.833 & -0.234 & \\
#  0.808 & 0.470 & -1.430 & 0.466 & 0.097 & 0.399 & 1.653 & 0.028 & -0.463 & 0.584 & \\
#  0.379 & -0.311 & 0.428 & 0.201 & -0.144 & 0.980 & -2.000 & 0.903 & 1.152 & 0.465 & \\
#  -0.245 & 0.058 & -1.344 & -0.554 & 0.661 & -0.292 & 0.429 & 0.282 & -0.308 & 0.122 & \\
#  0.376 & 0.047 & -2.278 & -0.468 & -0.176 & 0.850 & 0.287 & 0.789 & 0.926 & 1.885 & \\
#  -1.614 & -0.246 & 0.118 & 0.917 & -1.942 & 0.003 & 0.767 & 1.488 & 0.672 & -2.309 & \\
#  0.529 & -0.528 & 0.196 & 3.367 & 1.294 & 0.349 & -0.533 & -0.213 & -0.776 & 0.210 & \\
#  1.621 & 0.390 & -0.741 & 0.738 & -1.274 & 1.633 & 0.900 & -1.835 & -1.183 & 1.183 & \\
#  -0.510 & -1.048 & 1.007 & 1.251 & -0.264 & 0.708 & 1.077 & 0.167 & -0.396 & -0.376 & \\
#  0.867 & 0.029 & -0.793 & 0.242 & 0.012 & -0.192 & -0.159 & 1.190 & 0.391 & 0.942 & \\
#  0.788 & 1.341 & 0.084 & 0.657 & 0.494 & -0.179 & 1.789 & -1.010 & -0.163 & -0.265 & \\
#  -1.705 & -0.640 & 0.771 & -1.111 & -0.578 & -1.360 & 1.990 & 0.478 & 0.355 & 0.866 & \\
#  0.031 & -0.546 & -0.428 & 2.748 & -0.204 & -0.494 & 1.355 & 0.855 & -1.024 & -0.680 & \\
#  -0.151 & 0.020 & 0.349 & 2.952 & 0.172 & -0.617 & -0.141 & 1.936 & -0.311 & 0.878 & \\
#  -0.488 & -1.351 & 0.939 & 0.514 & -0.936 & -1.018 & 0.271 & -0.401 & 0.420 & -0.570 & \\
#  1.497 & -2.075 & 1.923 & -0.532 & 0.020 & -0.495 & 0.058 & -1.851 & 1.147 & -1.284 & \\
#  -0.040 & 1.655 & 0.808 & 0.632 & -0.537 & -0.131 & 1.413 & -0.495 & 0.511 & -0.547 & \\
#  0.965 & 0.040 & -0.138 & -1.027 & 1.341 & 1.401 & 2.355 & -1.237 & 2.374 & 0.895 & \\
#  -0.270 & -0.008 & 2.156 & -0.277 & -0.317 & -0.234 & -0.973 & -0.865 & -1.352 & 1.821 & \\
#  -0.048 & -0.826 & 0.711 & -0.338 & 0.159 & 0.265 & -0.853 & 0.047 & 0.746 & -1.892 & \\
#  -0.867 & 0.296 & -1.011 & -0.528 & 0.039 & 0.495 & -0.794 & 0.614 & 0.110 & 0.752 & \\
#  -0.829 & 0.073 & 2.052 & -0.577 & -0.579 & -0.737 & 0.257 & -0.942 & 0.171 & 0.052 & \\
#  -1.434 & 0.290 & 0.670 & -1.157 & 1.085 & 1.029 & 1.157 & 0.205 & 0.589 & -1.249 & \\
#  1.657 & -0.870 & 0.172 & 0.259 & 0.490 & 0.996 & 0.174 & -0.478 & -0.225 & -0.167 & \\
#  0.473 & 0.627 & 0.403 & -0.469 & 1.917 & 1.309 & 2.348 & 0.483 & 2.635 & -2.471 & \\
#  1.842 & -1.293 & -0.267 & 0.375 & 0.943 & -0.777 & -2.437 & -1.498 & 1.673 & 1.247 & \\
#  -1.568 & -1.237 & -0.859 & -0.476 & 0.488 & 0.197 & -0.720 & -0.974 & -0.292 & -0.164 & \\
#  0.770 & 0.212 & -0.998 & -2.758 & 1.626 & 0.510 & -1.818 & -0.535 & 1.368 & 0.218 & \\
#  -0.381 & -0.488 & 1.056 & 0.707 & -2.261 & 0.924 & -0.269 & 1.110 & 1.829 & -1.190 & \\
#  1.789 & 0.115 & -0.463 & 1.644 & -0.741 & -0.124 & -1.349 & 0.332 & 0.350 & -1.368 & \\
#  0.605 & -0.678 & 1.014 & -1.535 & -0.507 & -0.863 & 1.372 & 0.969 & 0.128 & 1.031 & \\
#  -1.541 & 0.411 & 0.418 & -0.809 & -1.544 & 1.442 & -0.130 & -0.006 & -0.423 & -0.268 & \\
#  -0.865 & 2.384 & 0.846 & -0.429 & -1.364 & 1.096 & 0.117 & 0.244 & 0.113 & -0.088 & \\
#  0.934 & -0.550 & 1.985 & -1.934 & 0.437 & 0.201 & 2.124 & -1.240 & 0.150 & -1.467 & \\
#  0.716 & 0.567 & 1.598 & 0.106 & -0.118 & 0.461 & -1.805 & 1.835 & 0.614 & -1.308 & \\
# \end{bmatrix}$
# Input SNR is : 29.97981998399493

# %%
s_dim = S.shape[0]
x_dim = X.shape[0]
debug_iteration_point = 5000
model = RVolMin(s_dim = s_dim, x_dim = x_dim,
                set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch(X, n_iterations = 25000,
                Lt = 1000, p = 0.01,
#                 lambda_ = 28, tau = 1e-10, 
                debug_iteration_point = debug_iteration_point,
                plot_in_jupyter = True)
# Out:
#  52%|█████▏    | 13037/25000 [02:40<01:42, 116.77it/s]

# %%
U, singulars, V = np.linalg.svd(X, full_matrices=False)
s_dim = S.shape[0]
x_dim = X.shape[0]
samples = X.shape[1]
C = V[0:s_dim,:]
B = U[:,:s_dim]
F = np.eye(s_dim)
W = np.eye(samples)
W = np.diag(np.diag(np.random.randn(samples, samples)))
w =np.diag(W).reshape(-1,1)
q = 1
p = 1
Lt = 5
lambda_ = 0.1
epsilon = 1e-8
tau = 1e-8

# %%
diff = C.copy()
Cprev = C.copy()
q_prev = q
q = (1+math.sqrt(1+4*q*q))/2
C = C + ((q_prev - 1)/q)*(diff)
C = C - (np.dot(B.T,(np.dot(B, C) - X))/(Lt*np.linalg.norm(np.transpose(B)@B, 2)))
C = ProjectColstoSimplex(C)
diff = C - Cprev

# %%
# %timeit a = X @ W.T @ C.T @ np.linalg.pinv(C @ W.T @ C.T + lambda_* F)

# %%
# %timeit b = (X * w.T) @ C.T @ np.linalg.pinv( (C * w.T) @ C.T + lambda_ * F)

# %%
# %timeit c = np.linalg.solve(((C * w.T) @ C.T + lambda_ * F).T, ((X * w.T) @ C.T).T).T

# %%
np.linalg.norm(a - c)

# %%
k = -2
(np.linalg.norm(X[:,k] - B @ C[:,k])**2 + epsilon) **((p - 2)/2)

# %%
((p / 2) * (np.sum((X - B @ C) ** 2, axis = 0) + epsilon)**((p - 2)/2))[:,np.newaxis]

# %%
p = 0.01
((p / 2) * (np.sum((X - B @ C) ** 2, axis = 0) + epsilon)**((p - 2)/2))[:,np.newaxis]
