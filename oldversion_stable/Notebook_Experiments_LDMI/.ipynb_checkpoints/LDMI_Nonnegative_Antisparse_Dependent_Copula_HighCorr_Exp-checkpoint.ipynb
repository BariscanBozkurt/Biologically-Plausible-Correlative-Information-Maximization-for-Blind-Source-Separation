# %% [markdown]
# # Import Required Libraries

# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
# np.random.seed(100)
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Source Generation and Mixing Scenario

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.7, df = 4, n_sources = NumberofSources, 
                                       size_sources = N , decreasing_correlation = False)

print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

SNR = 30
X, NoisePart = addWGN(X, SNR, return_noise = True)

SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.668 & 0.668 & 0.668 & 0.667 & \\
#  0.668 & 1.000 & 0.666 & 0.667 & 0.667 & \\
#  0.668 & 0.666 & 1.000 & 0.668 & 0.667 & \\
#  0.668 & 0.667 & 0.668 & 1.000 & 0.668 & \\
#  0.667 & 0.667 & 0.667 & 0.668 & 1.000 & \\
# \end{bmatrix}$
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.171 & -1.449 & 0.017 & 0.432 & 1.671 & \\
#  0.905 & -0.820 & -1.228 & -0.942 & 0.355 & \\
#  1.260 & 1.083 & 0.050 & -0.252 & 0.086 & \\
#  1.245 & 0.149 & 0.297 & 1.802 & 0.305 & \\
#  -0.655 & 0.118 & 2.964 & 0.114 & -0.970 & \\
#  1.493 & 0.607 & 0.015 & 1.043 & 0.061 & \\
#  -0.944 & 0.272 & -1.909 & -0.552 & -0.806 & \\
#  0.134 & -1.191 & 0.153 & 1.485 & 2.249 & \\
#  1.533 & 0.600 & -0.714 & -0.771 & 0.308 & \\
#  0.941 & 0.068 & -0.164 & 0.523 & 0.034 & \\
# \end{bmatrix}$
# Input SNR is : 30.002480273389946

# %% [markdown]
# # Visualize Generated Sources and Mixtures

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %% [markdown]
# # Algorithm Hyperparameter Selection and Weight Initialization

# %%
lambday = 1 - 1e-1/10
lambdae = 1 - 1e-1/3
s_dim = S.shape[0]
x_dim = X.shape[0]

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 1000 * np.eye(s_dim)

debug_iteration_point = 10000
model = OnlineLDMIBSS(s_dim = s_dim, x_dim = x_dim, muW = 30*1e-3, lambday = lambday,
                      lambdae = lambdae, By = By, Be = Be, neural_OUTPUT_COMP_TOL = 1e-6,
                      set_ground_truth = True, S = S, A = A)

# %% [markdown]
# # Run CorInfoMax Algorithm on Mixture Signals

# %%
model.fit_batch_nnantisparse(X = X, n_epochs = 1, neural_dynamic_iterations = 500,
                           plot_in_jupyter = True, neural_lr_start = 0.9,
                           neural_lr_stop = 0.001, debug_iteration_point = debug_iteration_point, 
                           shuffle = True)
# Out:
# 100%|██████████| 500000/500000 [02:25<00:00, 3426.77it/s]

# %% [markdown]
# # Visualize SINR Convergence

# %%
mpl.rcParams['xtick.labelsize'] = 18
mpl.rcParams['ytick.labelsize'] = 18
plot_convergence_plot(model.SINR_list, xlabel = 'Number of Iterations / {}'.format(debug_iteration_point),
                     ylabel = 'SINR (dB)', title = 'SINR Convergence Plot', colorcode = None, linewidth = 1.8)

print('Final SINR: {}'.format(np.array(model.SINR_list[-1])))
# Out:
# Final SINR: 24.86612669731743

# %% [markdown]
# # Calculate Resulting Component SNRs and Overall SINR

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y_ = Wf @ X
Y_ = model.signed_and_permutation_corrected_sources(S.T,Y_.T)
coef_ = (Y_ * S.T).sum(axis = 0) / (Y_ * Y_).sum(axis = 0)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr(S.T, Y_)))

SINR = 10*np.log10(model.CalculateSINR(Y_.T, S)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [24.58317036 24.82732433  7.75015623 24.74292783 23.97609921]
#
# Overall SINR : 24.86612669731743

# %% [markdown]
# # Vizualize Extracted Signals Compared to Original Sources

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = model.signed_and_permutation_corrected_sources(S.T,Y.T).T
Y_.shape, X.shape, S.shape
# Out:
# ((5, 500000), (10, 500000), (5, 500000))

# %%
subplot_1D_signals(X = Y_.T[0:100], title = 'Extracted Signals (Sign and Permutation Corrected)' ,figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X = S.T[0:100], title = 'Original Signals' ,figsize = (15.2,9), colorcode = None)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y_ = Wf @ X
Y_ = model.signed_and_permutation_corrected_sources(S.T,Y_.T)
coef_ = (Y_ * S.T).sum(axis = 0) / (Y_ * Y_).sum(axis = 0)
Y_ = coef_ * Y_
snr(S.T.reshape(-1,1), Y_.reshape(-1,1))
# Out:
# array([14.39022842])

# %%
Out = Y_.T
r=S.shape[0]
G=np.dot(Out-np.reshape(np.mean(Out,1),(r,1)),np.linalg.pinv(S-np.reshape(np.mean(S,1),(r,1))))
indmax=np.argmax(np.abs(G),1)
indmax = np.mod(find_permutation_between_source_and_estimation(Out.T, S.T),r)
# indmax = np.array([2,3,4,1,0])
GG=np.zeros((r,r))
for kk in range(r):
    GG[kk,indmax[kk]]=np.dot(Out[kk,:]-np.mean(Out[kk,:]),S[indmax[kk],:].T-np.mean(S[indmax[kk],:]))/np.dot(S[indmax[kk],:]-np.mean(S[indmax[kk],:]),S[indmax[kk],:].T-np.mean(S[indmax[kk],:]))#(G[kk,indmax[kk]])
ZZ=GG@(S-np.reshape(np.mean(S,1),(r,1)))+np.reshape(np.mean(Out,1),(r,1))
E=Out-ZZ
MSE=np.linalg.norm(E,'fro')**2
SigPow=np.linalg.norm(ZZ,'fro')**2
SINR=(SigPow/MSE)

# %%
10*np.log10(SINR)
# Out:
# 14.630536962736684

# %%
indmax=np.argmax(np.abs(G),1)
indmax = np.mod(find_permutation_between_source_and_estimation(Out.T, S.T),r)
indmax
# Out:
# array([0, 2, 1, 3, 4])

# %%
display_matrix(G)
# Out:
# $\displaystyle \begin{bmatrix}
#  1.128 & -0.031 & -0.035 & -0.047 & -0.031 & \\
#  -0.027 & 1.053 & 0.021 & 0.002 & -0.058 & \\
#  -0.024 & 0.962 & 0.019 & 0.002 & -0.053 & \\
#  -0.045 & -0.055 & -0.002 & 1.102 & -0.013 & \\
#  -0.039 & -0.035 & -0.022 & -0.026 & 1.108 & \\
# \end{bmatrix}$

# %%
Y_.shape
# Out:
# (500000, 5)

# %%
snr(Y_[:,3], Y_[:,4])
# Out:
# 6.627273963248369

# %%
10*np.log10(SINR)
# Out:
# 14.630536962736684

# %%
find_permutation_between_source_and_estimation(Out.T, S.T)
# Out:
# array([0, 7, 6, 3, 4])

# %%
def find_permutation_between_source_and_estimation2(S,Y):
    """
    S    : Original source matrix
    Y    : Matrix of estimations of sources (after BSS or ICA algorithm)
    
    return the permutation of the source seperation algorithm
    """
    
    # perm = np.argmax(np.abs(np.corrcoef(S.T,Y.T) - np.eye(2*S.shape[1])),axis = 0)[S.shape[1]:]
    perm = np.argmax(np.abs(np.corrcoef(Y.T,S.T) - np.eye(2*S.shape[1])),axis = 0)[S.shape[1]:]
    return perm

# %%
np.mod(find_permutation_between_source_and_estimation2(Out.T, S.T), 5)
# Out:
# array([0, 2, 1, 3, 4])

# %%
10*np.log10(SINR)
# Out:
# 14.630536962736684

# %%
indmax
# Out:
# array([0, 2, 1, 3, 4])

# %%
10*np.log10(model.CalculateSINR(Y_.T, S)[0])
# Out:
# 24.86612669731743

# %%
display_matrix(G)
# Out:
# $\displaystyle \begin{bmatrix}
#  1.128 & -0.031 & -0.035 & -0.047 & -0.031 & \\
#  -0.027 & 1.053 & 0.021 & 0.002 & -0.058 & \\
#  -0.024 & 0.962 & 0.019 & 0.002 & -0.053 & \\
#  -0.045 & -0.055 & -0.002 & 1.102 & -0.013 & \\
#  -0.039 & -0.035 & -0.022 & -0.026 & 1.108 & \\
# \end{bmatrix}$

# %%
display_matrix(Wf @ A)
# Out:
# $\displaystyle \begin{bmatrix}
#  0.037 & 0.034 & 0.021 & 0.025 & -1.069 & \\
#  -1.107 & 0.030 & 0.034 & 0.046 & 0.030 & \\
#  0.027 & -1.080 & -0.022 & -0.002 & 0.060 & \\
#  0.045 & 0.055 & 0.002 & -1.110 & 0.013 & \\
#  0.071 & 0.044 & -1.126 & 0.046 & 0.050 & \\
# \end{bmatrix}$

# %%
import mir_eval

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S.T,Y.T).T

# %%
mir_eval.separation.bss_eval_sources(S, Y_,
                     compute_permutation=False)
# Out:
# (array([25.14368154, 24.92390726, 23.37879807, 25.09663707, 24.31732617]),
#  array([27.94114907, 32.18612269, 24.03678365, 29.27947948, 29.27776266]),
#  array([28.38475542, 25.83009351, 31.91642731, 27.18972874, 25.99175699]),
#  array([0, 1, 2, 3, 4]))

# %%
Wf = np.random.randn(Wf.shape[0], Wf.shape[1])
Y = Wf @ X
mir_eval.separation.bss_eval_sources(S, Y,
                     compute_permutation=True)
# Out:
# (array([14.32110811, 11.76323622, 10.41751363, 12.14063997, 12.13139633]),
#  array([14.54216834, 11.78834104, 10.89850117, 12.19141358, 12.17999582]),
#  array([27.51389093, 34.43463198, 20.55179955, 31.74205987, 31.92244605]),
#  array([1, 2, 3, 4, 0]))

# %%
snr(S.T, Y.T)
# Out:
# array([-18.64597182, -14.50800016, -25.74990528, -11.36082773,
#        -20.48119128])
