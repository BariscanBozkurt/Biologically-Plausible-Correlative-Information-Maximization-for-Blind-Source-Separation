# %%
import sys
import os
os.chdir("..")
os.chdir("./src")
# sys.path.append("./src")

# %%
from IPython import display
from IPython.display import clear_output
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
from numba import njit, jit
from time import time
# from helpers import *
from LDMIBSS import *
np.random.seed(13)
# %load_ext autoreload
# %autoreload 2

# %%
N = 500000
NumberofSources = 5
NumberofMixtures = 10
S = generate_correlated_copula_sources(rho = 0.0, df = 4, n_sources = NumberofSources, size_sources = N , decreasing_correlation = True)
# S = 2 * S - 1
nnsparse_components = [0,1,3,4]
# nn_components = [4]
S[nnsparse_components] = 2 * S[nnsparse_components] - 1
S[nnsparse_components] = ProjectRowstoL1NormBall(S[nnsparse_components].T).T
S[nnsparse_components] = S[nnsparse_components]*(S[nnsparse_components] >=0)
print("The following is the correlation matrix of sources")
display_matrix(np.corrcoef(S))

plt.scatter(S[0,:], S[2,:])
plt.show()

plt.scatter(S[0,:], S[1,:])
plt.show()

plt.scatter(S[0,:], S[4,:])
plt.show()
# Out:
# The following is the correlation matrix of sources
# $\displaystyle \begin{bmatrix}
#  1.000 & -0.090 & -0.000 & -0.091 & -0.089 & \\
#  -0.090 & 1.000 & 0.001 & -0.087 & -0.089 & \\
#  -0.000 & 0.001 & 1.000 & 0.002 & 0.000 & \\
#  -0.091 & -0.087 & 0.002 & 1.000 & -0.086 & \\
#  -0.089 & -0.089 & 0.000 & -0.086 & 1.000 & \\
# \end{bmatrix}$

# %%
# Generate Mxr random mixing from i.i.d N(0,1)
A = np.random.randn(NumberofMixtures,NumberofSources)
X = np.dot(A,S)

print("The following is the mixture matrix A")
display_matrix(A)

SNR = 30 # dB
NoiseAmp = (10 ** (-SNR/20))# * np.sqrt(NumberofSources)
NoisePart = NoiseAmp * np.random.randn(X.shape[0], X.shape[1])
X = X  + NoisePart
SNRinp = 10 * np.log10(np.sum(np.var(X, axis = 1)) / np.sum(np.var(NoisePart, axis = 1)))
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  0.453 & -0.083 & -0.125 & -0.218 & -0.269 & \\
#  -0.605 & 1.323 & 1.034 & 0.184 & -1.564 & \\
#  -0.593 & 0.613 & 1.551 & -0.102 & -0.282 & \\
#  -0.895 & -1.093 & 0.066 & 0.473 & -0.868 & \\
#  -0.046 & -0.608 & 0.823 & 0.374 & -0.100 & \\
#  -0.267 & -0.500 & -1.359 & 0.185 & -0.180 & \\
#  -0.091 & -1.240 & 0.945 & -0.120 & 1.268 & \\
#  0.651 & 0.399 & 0.081 & 0.164 & 0.458 & \\
#  -1.083 & 1.754 & 0.095 & 1.065 & 1.247 & \\
#  1.010 & 0.533 & 0.414 & 0.247 & 0.487 & \\
# \end{bmatrix}$
# Input SNR is : 21.28618413279119

# %%
subplot_1D_signals(S.T[0:100], title = 'Original Signals', figsize = (15.2,9), colorcode = None)
subplot_1D_signals(X.T[0:100], title = 'Mixture Signals', figsize = (15,18), colorcode = None)

# %%
lambday = 1 - 1e-1/10
lambdae = 1 - 1e-7/10
beta = 15
s_dim = S.shape[0]
x_dim = X.shape[0]

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 1 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineLDMIBSS(s_dim = s_dim, x_dim = x_dim, muW = 1e-3, lambday = lambday,
                      lambdae = lambdae, beta = beta, By = By, Be = Be, neural_OUTPUT_COMP_TOL = 1e-6,
                      set_ground_truth = True, S = S, A = A)

# %%
model.fit_batch_nnwsubnnsparse(X = X, nnsparse_components = nnsparse_components,
                                 n_epochs = 1, neural_dynamic_iterations = 500,
                                 plot_in_jupyter = True, neural_lr_start = 0.25,
                                 neural_lr_stop = 0.001, debug_iteration_point = debug_iteration_point, 
                                 shuffle = True)
# Out:
# 100%|█████████████████████████████████| 500000/500000 [01:52<00:00, 4442.06it/s]
