# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 10000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 5,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=6,
        neural_lr_stop=1e-8,
        stlambd_lr=2e-2,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|██████████| 312500/312500 [2:28:44<00:00, 35.02it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.79254754e-02,  6.32183211e-03,  5.24086451e-03, ...,
#          7.57554601e-04,  2.77398958e-04,  6.07258106e-05],
#        [-3.02028451e-03, -1.48015865e-02,  1.07804886e-02, ...,
#          5.32390783e-04,  3.61197498e-04, -2.42919729e-04],
#        [-4.77415203e-05, -1.90554793e-03, -1.45364561e-02, ...,
#         -1.32122085e-05,  2.37926458e-04, -4.70137313e-04],
#        ...,
#        [ 3.99053396e-04, -4.25736431e-04,  6.85587385e-04, ...,
#         -7.44953505e-03, -3.74375292e-03, -1.44213724e-03],
#        [ 3.24873471e-04,  8.87896537e-05, -3.00736369e-04, ...,
#          1.23330394e-02, -1.52593410e-02, -2.97406307e-03],
#        [ 1.96894692e-05, -1.24712874e-04, -3.19739744e-04, ...,
#         -6.00343353e-04, -5.08385160e-03, -1.91635823e-02]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.83803115749192

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    
plt.savefig("SparseCopy2.png")
