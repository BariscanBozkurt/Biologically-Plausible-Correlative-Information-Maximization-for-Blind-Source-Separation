# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 10000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 6,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=1.5,
        neural_lr_stop=1e-8,
        stlambd_lr=2e-2,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|██████████| 312500/312500 [2:18:56<00:00, 37.49it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.85495015e-02, -8.54558400e-03, -5.63640845e-04, ...,
#          5.01230166e-04, -4.17959854e-05,  1.74425256e-04],
#        [ 4.40472577e-03, -1.71151771e-02,  1.11328269e-02, ...,
#          4.44879801e-04,  3.44946824e-04,  2.86985656e-04],
#        [ 2.58302912e-03, -6.53355107e-03, -1.99846057e-02, ...,
#         -7.74137622e-05,  2.84609679e-04,  5.86683564e-04],
#        ...,
#        [ 1.61046140e-05,  3.07037267e-04,  4.10968813e-04, ...,
#         -2.05775598e-02,  1.86015041e-03,  6.48444998e-04],
#        [ 4.18748857e-05, -1.66316589e-04,  1.87635423e-04, ...,
#         -9.30247704e-04, -1.81804454e-02,  1.47836323e-02],
#        [-3.88795298e-04,  6.14746860e-04,  1.44147652e-04, ...,
#         -7.54146506e-04, -1.27482040e-02, -1.01843610e-02]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.817746136312197

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    
plt.savefig("SparseCopy3.png")
