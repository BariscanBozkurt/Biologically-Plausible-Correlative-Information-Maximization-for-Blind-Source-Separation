# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Nonnegative_Antisparse_Copula'

# np.random.seed(250)

# %%
image_paths = '../../data/TestImages'
images = []
for im_dir in os.listdir(image_paths):
    try:
        images.append(mpimg.imread(os.path.join(image_paths,im_dir)))
    except:
        pass
images = np.array(images)

# %%
small_images = np.zeros((images.shape[0],324* 432* 3))
small_to_large_image_size_ratio = 0.1
for i in range(images.shape[0]):
    small_img = cv2.resize(images[i], # original image
                           (0,0), # set fx and fy, not the final size
                           fx=small_to_large_image_size_ratio, 
                           fy=small_to_large_image_size_ratio, 
                           interpolation=cv2.INTER_NEAREST)
    if small_img.shape[0] == 302:
        small_img = cv2.resize(small_img, (0,0), fx = 432/403, fy = 324/302)
    print(small_img.shape)
    small_images[i] = small_img.reshape(-1,)/255

small_images.shape
# Out:
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (324, 432, 3)
# (14, 419904)

# %%
S = small_images[[12,6,10]]
Subplot_RGB_images(S, imsize = [324,432], height = 4, width = 18)
display_matrix(np.corrcoef(S))
# plt.savefig('Original_Images.pdf', format = 'pdf', dpi = 1500)

# S = small_images[[0,2,3]]
# Subplot_RGB_images(S, imsize = [324,432], height = 4, width = 18)
# display_matrix(np.corrcoef(S))
# plt.savefig('Original_Images.pdf', format = 'pdf', dpi = 1500)
# Out:
# $\displaystyle \begin{bmatrix}
#  1.000 & 0.078 & 0.292 & \\
#  0.078 & 1.000 & 0.320 & \\
#  0.292 & 0.320 & 1.000 & \\
# \end{bmatrix}$

# %%
# # np.random.seed(1000)
# # NumberofMixtures = 6
# # NumberofSources = 3
# # # Generate Mxr random mixing from i.i.d N(0,1)
# # A = np.random.randn(NumberofMixtures,NumberofSources)#/1.3
# # # A = np.random.uniform(-0.5, 0.5, (NumberofMixtures,NumberofSources))
# # X = np.dot(A,S)

# # SNR = 40
# # X, NoisePart = addWGN(X, SNR, return_noise = True)

# # SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
# # print("The following is the mixture matrix A")
# # display_matrix(A)
# # print("Input SNR is : {}".format(SNRinp))

# # X_ = ZeroOneNormalizeColumns(X.T).T # For image plotting of mixtures

# # np.random.seed(50)
# NumberofMixtures = 5
# NumberofSources = 3
# # S_ = 2 * S - 1
# INPUT_STD = 0.28
# A = np.random.standard_normal(size=(NumberofMixtures,NumberofSources))
# # A = np.random.uniform(size=(NumberofMixtures,NumberofSources))
# X = A @ S
# X1 = X.copy()
# for M in range(A.shape[0]):
#     stdx = np.std(X[M,:])
#     A[M,:] = A[M,:]/stdx * INPUT_STD
    
# SNR=40
# # A = np.abs(A)
# Xn = A @ S
# X, NoisePart = addWGN(Xn, SNR, return_noise = True)

# SNRinp = 10 * np.log10(np.sum(np.mean((X - NoisePart)**2, axis = 1)) / np.sum(np.mean(NoisePart**2, axis = 1)))
# print("The following is the mixture matrix A")
# display_matrix(A)
# print("Input SNR is : {}".format(SNRinp))

# X_ = ZeroOneNormalizeColumns(X.T).T
# print('The following is the mixture matrix')
# display_matrix(A)

np.random.seed(350)
NumberofMixtures = 5
NumberofSources = 3

INPUT_STD = 0.28

A, X = WSM_Mixing_Scenario(S, NumberofMixtures, INPUT_STD)
A = np.random.randn(NumberofMixtures,NumberofSources)#/1.3
# np.random.seed(100)

# A = np.random.standard_normal((NumberofMixtures, NumberofSources))
# minA = np.min(A)
# min_abs = np.abs(minA)

# for i in range(NumberofMixtures):
#     for j in range(NumberofSources):
#         if A[i, j] <= 0:
#             A[i, j] += min_abs + 0.1
#         elif A[i, j] + minA >= 0:
#             A[i, j] += minA
        
X = np.dot(A,S)
SNR = 40

X, NoisePart = addWGN(X, SNR, return_noise=True)

SNRinp = 10 * np.log10(
    np.sum(np.mean((X - NoisePart) ** 2, axis=1))
    / np.sum(np.mean(NoisePart**2, axis=1))
)

X_ = ZeroOneNormalizeColumns(X.T).T
print("The following is the mixture matrix A")
display_matrix(A)
print("Input SNR is : {}".format(SNRinp))
# Out:
# The following is the mixture matrix A
# $\displaystyle \begin{bmatrix}
#  1.390 & -0.870 & 0.901 & \\
#  -1.698 & -0.000 & -1.326 & \\
#  -1.127 & 0.982 & -0.151 & \\
#  0.271 & 1.466 & 0.036 & \\
#  0.746 & -1.135 & -1.645 & \\
# \end{bmatrix}$
# Input SNR is : 40.00580703559461

# %%
X.std(1)
# Out:
# array([0.45326671, 0.59309261, 0.33962835, 0.33714749, 0.51587815])

# %%
Subplot_RGB_images(X_, imsize = [324,432], height = 3, width = 18)
# plt.savefig('Mixture_Images.pdf', format = 'pdf', dpi = 1500)

# %%
subplot_1D_signals(S[:,1000:1200], title = 'Original Signals', figsize = (15.2,9), colorcode = None)

# %%
plt.figure()
plt.scatter(S[0,:], S[1,:])
plt.figure()
plt.scatter(S[1,:], S[2,:])
plt.figure()
plt.scatter(S[0,:], S[2,:])

# %%
# # lambday = 1 - 1e-1/10
# # lambdae = 1 - 1e-1/10
# s_dim = S.shape[0]
# x_dim = X.shape[0]

# lambday = 1 - 1e-1/5
# lambdae = 0.3

# # Inverse output covariance
# By = 1 * np.eye(s_dim)
# # Inverse error covariance
# Be = 250 * np.eye(s_dim)

# debug_iteration_point = 25000
# model = OnlineCorInfoMax(s_dim = s_dim, x_dim = x_dim, muW =  100*1e-3, lambday = lambday,
#                          lambdae = lambdae, By = By, Be = Be, neural_OUTPUT_COMP_TOL = 1e-6,
#                          set_ground_truth = True, S = S, A = A)

lambday = 1 - 1e-1/5
lambdae = 0.3

s_dim = S.shape[0]
x_dim = X.shape[0]

n_samples = X.shape[1]
n_iter = n_samples
ppf = X.shape[1]
Wf_arr = []

# Inverse output covariance
By = 1 * np.eye(s_dim)
# Inverse error covariance
Be = 50 * np.eye(s_dim)

debug_iteration_point = 2500
model = CorInfoMaxVideoSeparation(  s_dim = s_dim, x_dim = x_dim, muW = 25*1e-3, lambday = lambday,
                                    lambdae = lambdae, By = By, Be = Be, neural_OUTPUT_COMP_TOL = 1e-6,
                                    set_ground_truth = True, S = S, A = A)

aa = model.seperate_videos(Wf_list = Wf_arr, n_pixel_per_frame = ppf, X = X.reshape(1,NumberofMixtures, -1), 
                           n_iter = n_iter, neural_dynamic_iterations = 500,
                           plot_in_jupyter = True, neural_lr_start = 0.5,
                           neural_lr_stop = 0.001, debug_iteration_point = debug_iteration_point, 
                           shuffle = True)
# Out:
#  75%|███████▍  | 391671/525000 [01:47<00:34, 3907.33it/s]

# %%
# with Timer() as t:
#     model.fit_batch_nnantisparse(X = X, n_epochs = 1, neural_dynamic_iterations = 500,
#                                  neural_lr_start = 0.5,
#                                  neural_lr_stop = 0.001, 
#                                  plot_in_jupyter = True,
#                                  debug_iteration_point = debug_iteration_point, 
#                                  shuffle = True)
# print('Algorithm took %f sec.' % (t.interval))
# Out:
#  56%|█████▌    | 233777/419904 [02:23<01:54, 1632.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [32], in <module>
#       1 with Timer() as t:
# ----> 2     model.fit_batch_nnantisparse(X = X, n_epochs = 1, neural_dynamic_iterations = 500,
#       3                                  neural_lr_start = 0.5,
#       4                                  neural_lr_stop = 0.001,
#       5                                  plot_in_jupyter = True,
#       6                                  debug_iteration_point = debug_iteration_point,
#       7                                  shuffle = True)
#       8 print('Algorithm took %f sec.' % (t.interval))
#
# File /scratch/users/bbozkurt15/LDMI_OnlineCorInfoMax/Biologically-Plausible-Correlative-Information-Maximization-for-Blind-Source-Separation/Simulations/ImageSeparation/../../src/CorInfoMaxBSS.py:886, in OnlineCorInfoMax.fit_batch_nnantisparse(self, X, n_epochs, neural_dynamic_iterations, neural_lr_start, neural_lr_stop, synaptic_lr_rule, synaptic_lr_decay_divider, neural_loop_lr_rule, neural_lr_decay_multiplier, use_error_corr_structured_connectivity, shuffle, debug_iteration_point, plot_in_jupyter)
#     882 y = np.zeros(self.s_dim)
#     883 # y = np.random.uniform(0,1, size = (self.s_dim,))
#     884 # Output recurrent weights
#     885 # My = By + h * np.eye(self.s_dim)
# --> 886 y = self.run_neural_dynamics_nnantisparse(
#     887     x_current,
#     888     y,
#     889     W,
#     890     By,
#     891     Be,
#     892     gamy,
#     893     game,
#     894     lr_start=neural_lr_start,
#     895     lr_stop=neural_lr_stop,
#     896     lr_rule=neural_loop_lr_rule,
#     897     lr_decay_multiplier=neural_lr_decay_multiplier,
#     898     neural_dynamic_iterations=neural_dynamic_iterations,
#     899     neural_OUTPUT_COMP_TOL=neural_dynamic_tol,
#     900 )
#     902 e = y - W @ x_current
#     904 if synaptic_lr_rule == "constant":
#
# File ~/.conda/envs/wsm/lib/python3.8/site-packages/numba/core/serialize.py:29, in _numba_unpickle(address, bytedata, hashed)
#      25 # Keep unpickled object via `numba_unpickle` alive.
#      26 _unpickled_memo = {}
# ---> 29 def _numba_unpickle(address, bytedata, hashed):
#      30     """Used by `numba_unpickle` from _helperlib.c
#      31
#      32     Parameters
#    (...)
#      41         unpickled object
#      42     """
#      43     key = (address, hashed)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x2ac623c3d790> (for post_execute):
# KeyboardInterrupt

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
Y = Wf @ X
Y_ = signed_and_permutation_corrected_sources(S,Y)
coef_ = ((Y_ * S).sum(axis = 1) / (Y_ * Y_).sum(axis = 1)).reshape(-1,1)
Y_ = coef_ * Y_

print("Component SNR Values : {}\n".format(snr_jit(S, Y_)))

SINR = 10*np.log10(CalculateSINRjit(Y_, S, False)[0])

print("Overall SINR : {}".format(SINR))
# Out:
# Component SNR Values : [ 6.18979933  5.57297511 24.21976473]
#
# Overall SINR : 11.097716852517692

# %%
CalculateSIR(A,Wf)
# Out:
# (19.235080378455258, 3)

# %%
display_matrix(Wf @A)
# Out:
# $\displaystyle \begin{bmatrix}
#  0.043 & -1.066 & 0.061 & \\
#  0.083 & 0.161 & -1.271 & \\
#  -1.140 & 0.017 & 0.099 & \\
# \end{bmatrix}$

# %%
Subplot_RGB_images(ZeroOneNormalizeColumns(-Y_.T).T, imsize = [324,432], height = 4, width = 18)

# %%
Subplot_RGB_images(ZeroOneNormalizeColumns(-Y.T).T, imsize = [324,432], height = 4, width = 18)

# %%
Subplot_RGB_images(np.clip(Y_, 0,1), imsize = [324,432], height = 4, width = 18)

# %%
np.linalg.svd(Wf @ A)
# Out:
# (array([[ 0.46798895, -0.87514777, -0.12289314],
#         [ 0.61211705,  0.42130364, -0.66919053],
#         [ 0.63741593,  0.23794879,  0.73285832]]),
#  array([1.04311907, 0.90654907, 0.85495054]),
#  array([[-0.72013989, -0.43290696, -0.54220854],
#         [-0.67512882,  0.25700348,  0.69148412],
#         [-0.15999881,  0.86402591, -0.47734642]]))

# %%
display_matrix(Wf @ A)
# Out:
# $\displaystyle \begin{bmatrix}
#  0.201 & -0.506 & -0.763 & \\
#  -0.626 & -0.673 & 0.191 & \\
#  -0.725 & 0.309 & -0.510 & \\
# \end{bmatrix}$
