# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 10000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 7,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=5,
        neural_lr_stop=1e-8,
        stlambd_lr=0.06,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|█████████▉| 312495/312500 [5:03:20<00:00, 72.91it/s]
# 100%|██████████| 312500/312500 [5:03:21<00:00, 17.17it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.23060605e-02, -1.19475677e-02, -8.75842156e-03, ...,
#          6.59865199e-04,  3.97579055e-05,  5.35450864e-05],
#        [ 1.67084503e-02, -1.47502425e-02, -3.06368627e-03, ...,
#          1.00044551e-04,  4.97498448e-05, -3.18284775e-05],
#        [ 6.46074825e-03,  8.16829177e-03, -1.96037860e-02, ...,
#          1.65014177e-05,  1.57264316e-04, -8.11221848e-04],
#        ...,
#        [ 2.62535757e-04, -2.22301248e-04, -2.94135402e-04, ...,
#         -1.88763293e-02, -8.16200838e-05, -3.27249653e-04],
#        [ 4.14472716e-04,  2.54706008e-04,  5.25797786e-05, ...,
#          3.90022778e-03, -1.99929800e-02,  9.41664059e-03],
#        [-2.53748990e-04, -3.11542807e-04,  7.01492395e-07, ...,
#          2.40718885e-03, -1.01862983e-02, -1.70549015e-02]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.815552158963039

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    ax[l//12, l%12].axes.xaxis.set_visible(False)
    ax[l//12, l%12].axes.yaxis.set_visible(False)
plt.subplots_adjust( right=0.97,\
                    left=0.03,\
                    bottom=0.03,\
                    top=0.97,\
                    wspace=0.1,\
                    hspace=0.1)

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    
plt.savefig("Sparse1.png")
