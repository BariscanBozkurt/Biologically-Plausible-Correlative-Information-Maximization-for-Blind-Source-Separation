# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 10000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 7,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=5,
        neural_lr_stop=1e-8,
        stlambd_lr=2e-2,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|█████████▉| 311840/312500 [4:54:18<00:26, 25.30it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.48462040e-02, -1.07766672e-02, -2.11575710e-03, ...,
#          4.36476849e-04, -2.71930684e-04,  4.46084948e-04],
#        [ 9.85813202e-03, -1.76132698e-02,  3.84360514e-03, ...,
#         -4.17531480e-05, -6.97610131e-05, -3.24036316e-04],
#        [ 2.60996610e-03, -1.00528580e-03, -1.86068664e-02, ...,
#         -2.48351305e-04, -1.93596248e-05,  1.29922221e-04],
#        ...,
#        [ 3.25458727e-04,  4.19663817e-04, -1.43998088e-04, ...,
#         -6.74777377e-03, -4.63235576e-03, -5.34646910e-03],
#        [ 7.67088898e-05, -6.32554969e-04, -1.52112159e-04, ...,
#          1.36004321e-02, -1.68916665e-02, -2.38792670e-03],
#        [-2.21389501e-04, -1.92814235e-04, -1.81776080e-04, ...,
#          2.82663519e-03,  8.27014843e-03, -1.28981344e-02]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.8166908672902

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    
plt.savefig("Sparse1.png")
