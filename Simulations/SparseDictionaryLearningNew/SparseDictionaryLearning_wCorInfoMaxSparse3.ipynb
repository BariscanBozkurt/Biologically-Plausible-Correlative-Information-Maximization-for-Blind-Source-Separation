# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 20000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 5,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=1.5,
        neural_lr_stop=1e-8,
        stlambd_lr=2e-2,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|██████████| 312500/312500 [1:55:46<00:00, 44.99it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.20985486e-02,  5.86477307e-03,  2.50432703e-03, ...,
#          1.30662224e-04,  2.24002861e-05,  3.88078543e-04],
#        [-2.77449946e-03, -1.06175665e-02,  7.17014606e-03, ...,
#          6.09652610e-05, -1.68508226e-04,  2.55818725e-04],
#        [-8.99742829e-04, -1.56208774e-03, -1.24330514e-02, ...,
#          6.87790178e-05,  7.62519941e-05, -3.12201531e-04],
#        ...,
#        [-3.40624820e-05,  8.78747871e-05, -1.83001263e-05, ...,
#         -9.75441812e-03, -5.13518341e-03,  9.54962202e-04],
#        [ 2.23913546e-04,  2.53484132e-04,  1.37570948e-04, ...,
#          4.28081810e-03, -1.35418749e-02,  6.66506954e-03],
#        [-3.17979745e-04, -3.07743669e-04,  1.54630853e-04, ...,
#          2.10489524e-03, -6.57621277e-03, -8.95964017e-03]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.873841539734151

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    ax[l//12, l%12].axes.xaxis.set_visible(False)
    ax[l//12, l%12].axes.yaxis.set_visible(False)
plt.subplots_adjust( right=0.97,\
                    left=0.03,\
                    bottom=0.03,\
                    top=0.97,\
                    wspace=0.1,\
                    hspace=0.1)
plt.savefig("Sparse3.png")
