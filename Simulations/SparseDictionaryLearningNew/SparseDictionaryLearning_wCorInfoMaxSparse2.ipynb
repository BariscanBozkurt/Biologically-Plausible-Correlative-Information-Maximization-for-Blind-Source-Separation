# %%
import sys
import os
sys.path.append("../../src")
sys.path.append("../../data")
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from IPython import display
import pylab as pl

from CorInfoMaxBSS import *
from general_utils import *
from visualization_utils import * 

import warnings
warnings.filterwarnings("ignore")

notebook_name = 'Sparse_Dictionary_Learning'

# %%
image_paths = '../../data/Olshaussen'
X = scipy.io.loadmat(os.path.join(image_paths,'imagepatcheselfwhitened.mat'))['imagepatches']

# %%
# INPUT_STD = 0.5
# for MixtureIndex in range(X.shape[0]):
#     stdx = np.std(X[MixtureIndex,:])
#     X[MixtureIndex,:] = X[MixtureIndex,:]/stdx*INPUT_STD

# %%
lambday = 1 - 1e-3 / 10
lambdae = 1 - 1e-3 / 10
s_dim = 144
x_dim = 144

# Inverse output covariance
By = 5 * np.eye(s_dim)
# Inverse error covariance
Be = 25000 * np.eye(s_dim)

debug_iteration_point = 1000
model = OnlineCorInfoMaxOlshaussen(
    s_dim=s_dim,
    x_dim=x_dim,
    muW=1e-3 / 5,
    lambday=lambday,
    lambdae=lambdae,
    By=By,
    Be=Be,
    neural_OUTPUT_COMP_TOL=1e-6,
    set_ground_truth=False,
)

# %%
Wf = model.compute_overall_mapping(return_mapping = True)
model.plot_receptive_fields(Wf)

# %%
model.fit_batch(
        X,
        n_epochs=1,
        case = "sparse", # options: 'sparse' or 'nnsparse'
        neural_dynamic_iterations=500,
        neural_lr_start=1.5,
        neural_lr_stop=1e-8,
        stlambd_lr=2e-2,
        synaptic_lr_rule="constant",
        synaptic_lr_decay_divider=5000,
        neural_loop_lr_rule="divide_by_slow_loop_index",
        neural_lr_decay_multiplier=0.01,
        shuffle=True,
        debug_iteration_point=debug_iteration_point,
        plot_in_jupyter=True,
    )
# Out:
# 100%|██████████| 312500/312500 [1:53:53<00:00, 45.73it/s]

# %%
Wfend = model.compute_overall_mapping(return_mapping = True)
Wfend
# Out:
# array([[-1.11808581e-02, -3.66373897e-03, -1.18209544e-03, ...,
#          1.21529624e-04, -2.06855441e-04, -7.99498608e-05],
#        [ 3.74757287e-03, -1.14018770e-02,  4.95906383e-03, ...,
#          7.17436584e-05,  1.71944108e-05,  3.23935369e-05],
#        [ 5.00019464e-03, -3.60414701e-03, -1.11214947e-02, ...,
#          2.49603585e-04,  2.09599622e-04, -1.38390292e-04],
#        ...,
#        [ 2.31638981e-05, -6.49962286e-05, -1.73516190e-04, ...,
#         -1.19508098e-02,  1.39203551e-03, -1.21555947e-03],
#        [ 3.39220203e-04,  5.08545354e-05, -2.94746266e-04, ...,
#          2.89058091e-03, -1.17788220e-02, -7.93833656e-04],
#        [ 4.51212340e-05,  2.00670227e-04,  7.66773750e-05, ...,
#          1.35736570e-03,  2.43024899e-03, -1.01002938e-02]])

# %%
np.linalg.norm(Wfend - Wf)
# Out:
# 11.884246330570493

# %%
fig, ax = plt.subplots(12,12, figsize = (20,20))
for l in range(144):
    rf = np.reshape(-Wfend[l,:], (12,12))
    rf = ZeroOneNormalizeData(rf)
    ax[l//12, l%12].imshow(rf, cmap = 'gray')
    ax[l//12, l%12].axes.xaxis.set_visible(False)
    ax[l//12, l%12].axes.yaxis.set_visible(False)
plt.subplots_adjust( right=0.97,\
                    left=0.03,\
                    bottom=0.03,\
                    top=0.97,\
                    wspace=0.1,\
                    hspace=0.1)
plt.savefig("Sparse2.png")
